# %% [markdown]
# # Ingeniería de datos

# %%
# Librerias a usar
import os
import time
import pandas as pd
import numpy as np

# %%
df1 = "//192.168.1.2/cenyt-proyectos/CEN-221_ANDA/2.INFOENTRADA/5. Inspeccion Redes/2025-09-15/ANDA-REDES/registros_exportados_1758071892733.xlsx"

# %%
def limpiar_rutas_imagenes(ruta_archivo_excel, columnas_a_limpiar, prefijo_a_eliminar):
    """
    Lee un archivo de Excel, limpia las rutas de imágenes en las columnas especificadas
    y guarda el resultado en un nuevo archivo.

    Args:
        ruta_archivo_excel (str): La ruta completa del archivo de Excel de origen.
        columnas_a_limpiar (list): Una lista de los nombres de las columnas que contienen las rutas.
        prefijo_a_eliminar (str): El texto a eliminar de las rutas de las imágenes.

    Returns:
        str: La ruta del nuevo archivo de Excel creado.
    """
    
    # 1. Leer el archivo de Excel
    try:
        df = pd.read_excel(ruta_archivo_excel)
        print("Archivo de Excel leído exitosamente.")
    except FileNotFoundError:
        print(f"Error: El archivo no se encuentra en la ruta especificada: {ruta_archivo_excel}")
        return None
    
    # 2. Limpiar las columnas especificadas
    for columna in columnas_a_limpiar:
        if columna in df.columns:
            # Reemplazar el texto no deseado y asegurarse de que el tipo de dato sea string
            df[columna] = df[columna].astype(str).apply(lambda x: x.replace(prefijo_a_eliminar, '').strip())
            print(f"Columna '{columna}' procesada.")
        else:
            print(f"Advertencia: La columna '{columna}' no se encontró en el archivo.")
            
    # 3. Construir la nueva ruta del archivo de salida
    nombre_archivo, extension = os.path.splitext(ruta_archivo_excel)
    nueva_ruta_archivo = f"{nombre_archivo}_limpio{extension}"
    
    # 4. Guardar los cambios en un nuevo archivo de Excel
    df.to_excel(nueva_ruta_archivo, index=False)
    print(f"Datos limpios guardados en: {nueva_ruta_archivo}")
    
    return nueva_ruta_archivo

# --- Configuración y ejecución ---

# Define la ruta de tu archivo de Excel y el prefijo a eliminar
ruta_excel = df1# 👈 ¡Cambia esta ruta por la de tu archivo!
prefijo_a_quitar = "/storage/emulated/0/Download/RegistrosExportados/"

# Define las columnas a procesar
columnas_de_fotos = ["Foto1", "Foto2", "Foto3", "Foto4", "Foto5", "Foto6", "Foto7", "Foto8", "Foto9", "Foto10", "Foto11", "Foto12", "Foto13", "Foto14", "Foto15", "Foto16"]

# Llama a la función para limpiar las rutas
limpiar_rutas_imagenes(ruta_excel, columnas_de_fotos, prefijo_a_quitar)
# Out:
# Archivo de Excel leído exitosamente.
# Columna 'Foto1' procesada.
# Columna 'Foto2' procesada.
# Columna 'Foto3' procesada.
# Columna 'Foto4' procesada.
# Columna 'Foto5' procesada.
# Columna 'Foto6' procesada.
# Columna 'Foto7' procesada.
# Columna 'Foto8' procesada.
# Columna 'Foto9' procesada.
# Columna 'Foto10' procesada.
# Columna 'Foto11' procesada.
# Columna 'Foto12' procesada.
# Columna 'Foto13' procesada.
# Columna 'Foto14' procesada.
# Columna 'Foto15' procesada.
# Columna 'Foto16' procesada.
# Datos limpios guardados en: //192.168.1.2/cenyt-proyectos/CEN-221_ANDA/2.INFOENTRADA/5. Inspeccion Redes/2025-09-15/ANDA-REDES/registros_exportados_1758071892733_limpio.xlsx
# '//192.168.1.2/cenyt-proyectos/CEN-221_ANDA/2.INFOENTRADA/5. Inspeccion Redes/2025-09-15/ANDA-REDES/registros_exportados_1758071892733_limpio.xlsx'

# %%
import os
import pandas as pd
import glob

# --- CONFIGURACIÓN DE RUTAS ---
# La ruta de red de los datos de entrada
ruta_carpeta_entrada = r'C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\DATOS CRUDOS'

# La nueva ruta donde se guardará el archivo de salida
ruta_salida = r'C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\DATOS FINALES' # <--- CAMBIA ESTO A TU RUTA DESEADA
nombre_archivo_salida = 'proyecto_consolidado.xlsx'
ruta_completa_salida = os.path.join(ruta_salida, nombre_archivo_salida)

# --- CONFIGURACIÓN DE COLUMNAS Y DATOS ---
columnas_requeridas = ['ID_GPS1', 'ID_GPS2', 'ID_GPS3']
ruta_base_a_eliminar = '/storage/emulated/0/Download/RegistrosExportados/'
lista_dataframes = []

# --- 1. PROCESAR Y CONSOLIDAR ARCHIVOS ---
try:
    archivos = glob.glob(os.path.join(ruta_carpeta_entrada, '*.csv')) + \
               glob.glob(os.path.join(ruta_carpeta_entrada, '*.xlsx'))

    if not archivos:
        print(f"No se encontraron archivos .csv o .xlsx en la ruta: {ruta_carpeta_entrada}")
    else:
        for archivo in archivos:
            nombre_archivo = os.path.basename(archivo)
            print(f"Procesando archivo: {nombre_archivo}")

            try:
                if archivo.endswith('.csv'):
                    try:
                        df = pd.read_csv(archivo, encoding='utf-8', sep=';', on_bad_lines='skip')
                    except pd.errors.ParserError:
                        df = pd.read_csv(archivo, encoding='latin1', sep=';', on_bad_lines='skip')
                elif archivo.endswith('.xlsx'):
                    df = pd.read_excel(archivo)
                else:
                    print(f"  -> Tipo de archivo no soportado: {nombre_archivo}. Omitiendo.")
                    continue
                
                for col in columnas_requeridas:
                    if col not in df.columns:
                        print(f"  -> La columna '{col}' no existe. Creando y llenando con valores nulos.")
                        df[col] = pd.NA

                lista_dataframes.append(df)
            except Exception as e:
                print(f"  -> Error al leer o procesar el archivo {nombre_archivo}: {e}")

    if lista_dataframes:
        dataframe_final = pd.concat(lista_dataframes, ignore_index=True)
        print("\n¡Concatenación exitosa! DataFrame unificado creado.")
        
        # --- 2. PROCESAR LA COLUMNA 'Otras_Observaciones' Y LIMPIAR LA RUTA BASE ---
        if 'Otras_Observaciones' in dataframe_final.columns:
            print("\nProcesando la columna 'Otras_Observaciones'...")
            dataframe_final['Otras_Observaciones'] = dataframe_final['Otras_Observaciones'].fillna('')
            fotos_df = dataframe_final['Otras_Observaciones'].str.split(',', expand=True)
            
            # Limpiar la ruta base de las nuevas columnas de fotos
            for col in fotos_df.columns:
                fotos_df[col] = fotos_df[col].str.replace(ruta_base_a_eliminar, '', regex=False)
            
            fotos_df.columns = [f'Foto{i+1}' for i in fotos_df.columns]
            
            dataframe_final = pd.concat([dataframe_final, fotos_df], axis=1)
            dataframe_final.drop('Otras_Observaciones', axis=1, inplace=True)
            print("Columnas de fotos creadas y limpiadas exitosamente.")
        else:
            print("\nLa columna 'Otras_Observaciones' no se encontró. Este paso será omitido.")
            
        print("\nDataFrame final (primeras 5 filas):")
        print(dataframe_final.head())

        # --- 3. EXPORTAR EL DATAFRAME A UN ARCHIVO DE EXCEL ---
        if not os.path.exists(ruta_salida):
            os.makedirs(ruta_salida)
        
        dataframe_final.to_excel(ruta_completa_salida, index=False)
        print(f"\n¡Proyecto finalizado! El archivo se ha guardado exitosamente en: {ruta_completa_salida}")

    else:
        print("\nNo se pudo unificar ningún archivo. El DataFrame final está vacío.")
        dataframe_final = pd.DataFrame()

except Exception as e:
    print(f"Ocurrió un error al acceder a la ruta de red o guardar el archivo: {e}")
    dataframe_final = pd.DataFrame()
# Out:
# Procesando archivo: registros_exportados_1757459149029.csv
# Procesando archivo: registros_exportados_1758170527743.csv
# Procesando archivo: New Microsoft Excel Worksheet.xlsx
#
# ¡Concatenación exitosa! DataFrame unificado creado.
#
# Procesando la columna 'Otras_Observaciones'...
# Columnas de fotos creadas y limpiadas exitosamente.
#
# DataFrame final (primeras 5 filas):
#      ID            FechaHora NombreResponsable      Area           Circuito  \
# 0  39.0  2025-09-09 10:32:12             ANDA   EB3-EB2   SE CEL-Anda - EB2
# 1  38.0  2025-09-09 10:24:27             ANDA   EB3-EB2   SE CEL-Anda - EB2
# 2  37.0  2025-09-09 10:09:15             ANDA   EB3-EB2   SE CEL-Anda - EB2
# 3  36.0  2025-09-09 10:02:35             ANDA   EB3-EB2   SE CEL-Anda - EB2
# 4  35.0  2025-09-09 09:55:49             ANDA   EB3-EB2   SE CEL-Anda - EB2
#
#   Circuito_Observaciones Estructura_Tag  Latitud_GPS  Longitud_GPS  \
# 0                    NaN            114    13.838282    -89.262744
# 1                    NaN            114    13.838226    -89.262720
# 2                    NaN            113    13.837409    -89.261957
# 3                    NaN            112    13.836762    -89.261519
# 4                    NaN            111    13.836171    -89.260857
#
#    Latitud_Manual  ...                                         Foto3  \
# 0       13.838619  ...  JPEG_20250909_103726_3082911714446878058.jpg
# 1       13.838214  ...   JPEG_20250909_103148_387056503254547572.jpg
# 2       13.837339  ...  JPEG_20250909_101330_8270110169051264061.jpg
# 3       13.836811  ...  JPEG_20250909_100702_8810360956775359304.jpg
# 4       13.836114  ...  JPEG_20250909_095835_8298421170057916925.jpg
#
#                                           Foto4  \
# 0  JPEG_20250909_103753_1288292783344713862.jpg
# 1  JPEG_20250909_103158_7359467673026556756.jpg
# 2  JPEG_20250909_101355_1057902240100259176.jpg
# 3  JPEG_20250909_100713_4870020001005092149.jpg
# 4   JPEG_20250909_095845_105307550611538547.jpg
#
#                                           Foto5  \
# 0   JPEG_20250909_103843_166171686854279677.jpg
# 1                                          None
# 2  JPEG_20250909_101404_2374788593836607804.jpg
# 3                                          None
# 4  JPEG_20250909_100009_8362990185897573259.jpg
#
#                                           Foto6  \
# 0                                          None
# 1                                          None
# 2  JPEG_20250909_101418_8119938706699765431.jpg
# 3                                          None
# 4                                          None
#
#                                           Foto7 Foto8 Foto9 Foto10 Foto11  \
# 0                                          None  None  None   None   None
# 1                                          None  None  None   None   None
# 2  JPEG_20250909_101523_8539955755646891908.jpg  None  None   None   None
# 3                                          None  None  None   None   None
# 4                                          None  None  None   None   None
#
#   Foto12
# 0   None
# 1   None
# 2   None
# 3   None
# 4   None
#
# [5 rows x 82 columns]
#
# ¡Proyecto finalizado! El archivo se ha guardado exitosamente en: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\DATOS FINALES\proyecto_consolidado.xlsx

# %%
import pandas as pd
import openpyxl
import os
from openpyxl.drawing.image import Image

# --- CONFIGURACIÓN DE RUTAS ---
# La ruta del archivo de Excel consolidado que creamos
ruta_archivo_entrada = r'C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\DATOS FINALES\proyecto_consolidado.xlsx' # <--- ASEGÚRATE DE QUE SEA LA RUTA CORRECTA

# La ruta donde se encuentran las imágenes
ruta_carpeta_fotos = r'C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3'

# El nombre del nuevo archivo de Excel con las imágenes
nombre_archivo_salida_con_fotos = 'proyecto_consolidado_con_fotos.xlsx'

# Asegúrate de que la ruta de salida sea la misma que la de entrada, o una nueva si lo prefieres
ruta_completa_salida = os.path.join(os.path.dirname(ruta_archivo_entrada), nombre_archivo_salida_con_fotos)

# --- 1. LEER EL ARCHIVO CONSOLIDADO ---
print("Leyendo el archivo de Excel consolidado...")
try:
    df = pd.read_excel(ruta_archivo_entrada)
except FileNotFoundError:
    print(f"Error: El archivo de entrada no se encontró en la ruta: {ruta_archivo_entrada}")
    exit()

# --- 2. PREPARAR EL ARCHIVO DE EXCEL CON OPENPYXL ---
# Creamos un objeto de Excel a partir del DataFrame
workbook = openpyxl.Workbook()
sheet = workbook.active

# Escribimos los encabezados del DataFrame en la hoja de Excel
for col_num, column_title in enumerate(df.columns, 1):
    sheet.cell(row=1, column=col_num, value=column_title)

# Escribimos los datos del DataFrame en la hoja de Excel
for row_num, row_data in enumerate(df.values, 2):
    for col_num, cell_data in enumerate(row_data, 1):
        sheet.cell(row=row_num, column=col_num, value=cell_data)

print("Estructura de Excel preparada.")

# --- 3. INCRUSTAR LAS IMÁGENES ---
print("Buscando e incrustando imágenes...")
# Identificamos las columnas que contienen las rutas de las fotos (ej. 'Foto1', 'Foto2')
columnas_fotos = [col for col in df.columns if col.startswith('Foto')]

if not columnas_fotos:
    print("No se encontraron columnas de fotos ('Foto1', 'Foto2', etc.) en el archivo.")
else:
    for row_idx, row in df.iterrows():
        excel_row = row_idx + 2  # Las filas de Excel comienzan en 1 y los datos en la fila 2
        for foto_col in columnas_fotos:
            # Obtener el índice de la columna en el DataFrame
            df_col_idx = df.columns.get_loc(foto_col)
            excel_col = df_col_idx + 1 # Las columnas de Excel comienzan en 1
            
            # Obtener el nombre de la foto de la celda
            nombre_foto = row[foto_col]
            
            if pd.notna(nombre_foto) and nombre_foto: # Verificar si la celda no está vacía
                ruta_completa_foto = os.path.join(ruta_carpeta_fotos, nombre_foto)
                
                if os.path.exists(ruta_completa_foto):
                    try:
                        # Incrustar la imagen en la celda
                        img = Image(ruta_completa_foto)
                        # Opcional: ajustar el tamaño de la imagen si es necesario
                        # img.width = 100
                        # img.height = 100
                        sheet.add_image(img, sheet.cell(row=excel_row, column=excel_col).coordinate)
                        print(f"  -> Imagen incrustada: {nombre_foto} en la celda {sheet.cell(row=excel_row, column=excel_col).coordinate}")
                    except Exception as e:
                        print(f"  -> Error al incrustar la imagen {nombre_foto}: {e}")
                else:
                    print(f"  -> Archivo no encontrado: {ruta_completa_foto}")

print("\nProceso de incrustación de imágenes finalizado.")

# --- 4. GUARDAR EL NUEVO ARCHIVO DE EXCEL ---
try:
    workbook.save(ruta_completa_salida)
    print(f"\n¡Éxito! El archivo con las imágenes se ha guardado en: {ruta_completa_salida}")
except Exception as e:
    print(f"Error al guardar el archivo: {e}")
# Out:
# Leyendo el archivo de Excel consolidado...
# Estructura de Excel preparada.
# Buscando e incrustando imágenes...
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_103657_8675553972885569530.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_103709_1748070493310971728.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_103726_3082911714446878058.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_103753_1288292783344713862.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_103843_166171686854279677.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_102959_4309296348802395234.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_103109_1701519480144034068.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_103148_387056503254547572.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_103158_7359467673026556756.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_101148_4264364939518079590.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_101312_5092707080970990690.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_101330_8270110169051264061.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_101355_1057902240100259176.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_101404_2374788593836607804.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_101418_8119938706699765431.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_101523_8539955755646891908.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_100458_3566322066232758536.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_100552_2029878709056915901.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_100702_8810360956775359304.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_100713_4870020001005092149.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_095751_9193017400479635677.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_095819_6044160631814818582.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_095835_8298421170057916925.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_095845_105307550611538547.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_100009_8362990185897573259.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_095210_7648799971518745761.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_095221_1325345805868533141.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_095234_6770716888074003800.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_095255_8485103497227194451.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_095313_8485051777379864845.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_094452_9202112094346344035.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_094505_9079450774898281682.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_094529_469604769151737597.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_094538_890219342824764723.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_094631_262010524155651835.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_093156_4496919116851531028.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_093212_668338756417994194.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_093238_3001569546690979401.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_093248_2725543094700780222.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_093333_8774642339485284529.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_092535_3509718901889809036.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_092607_5893818445364131183.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_092637_8059569157617104665.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_092724_96495213544979534.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_092737_3809244273988160945.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_083312_6434251865409708111.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_083342_1933931705297113926.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_083354_5808595046989917089.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_083419_5160912830637594187.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_083437_7497730441424035287.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_082508_3351363355342600637.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_082518_6384822284895663107.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_082632_5914424329210359996.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_082710_5153859987891577632.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_081656_2432122210078191970.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_081736_8677306499865295787.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_081811_7313364565892451102.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_081823_7732532723741948629.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_081856_3021067034686540135.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_081120_1298985263490013493.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_081148_6240989248493362499.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_081203_3287109970365409629.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_081241_4284054611826287145.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_080236_767781284523666828.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_080314_1461999874650107588.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_080411_6044091636154043948.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_080514_4809514790849790790.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_075452_5400511972108010424.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_075522_6308203438033089190.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_075721_5303975834030325736.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_074958_1168088804490262333.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_075047_3358893540560578750.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_075116_5089052125900567750.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_075128_1521751918230945532.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_072051_4440677760486062808.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_072112_6397221088664257415.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_072140_5638561929083208339.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_072152_2912282878404651398.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_070723_6592292385444433086.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_070822_1028055003521840803.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_070858_2648313075801371003.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_071504_3594192751076827611.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_065819_4997108987318568354.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_065832_5510538342789925086.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_065859_99838862996267010.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_070104_7327031403299306346.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_065110_8143553673149873629.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_065122_5124720292395824923.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_065216_8910315892041965047.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_065348_5553499599789996163.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_063759_21762591110655275.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_064118_4179454655667723312.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_064134_2808173954305042962.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_064213_7406269760804386771.jpg
#   -> Imagen incrustada: IMG_20250908_213931_0.jpg en la celda BS23
#   -> Imagen incrustada: IMG_20250908_213931_1.jpg en la celda BT23
#   -> Imagen incrustada: IMG_20250908_213231_0.jpg en la celda BS24
#   -> Imagen incrustada: IMG_20250908_213231_1.jpg en la celda BT24
#   -> Imagen incrustada: IMG_20250908_213231_2.jpg en la celda BU24
#   -> Imagen incrustada: IMG_20250908_211009_0.jpg en la celda BS25
#   -> Imagen incrustada: IMG_20250908_211009_1.jpg en la celda BT25
#   -> Imagen incrustada: IMG_20250908_211009_2.jpg en la celda BU25
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_135117_7749079153358034877.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_135130_457672341649135895.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_134115_2342733842837251713.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_134124_8498382903328669655.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_134429_6593799742443069658.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_133617_3675133225002443549.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_133635_3394315743668251405.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_133651_7973242764941777187.jpg
#   -> Imagen incrustada: IMG_20250908_133053_0.jpg en la celda BS29
#   -> Imagen incrustada: IMG_20250908_133053_1.jpg en la celda BT29
#   -> Imagen incrustada: IMG_20250908_133053_2.jpg en la celda BU29
#   -> Imagen incrustada: IMG_20250908_133054_3.jpg en la celda BV29
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_133150_4461689700181560828.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_133212_7864214788445787088.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_133228_6711316216551751757.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_132205_3375586676343026023.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_132218_1550472402029601778.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_132241_6104245665123809811.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_132251_3689333305598792333.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_130743_6654708470999983521.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_130817_8507899591027461857.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_130836_7686240578942518024.jpg
#   -> Imagen incrustada: IMG_20250908_125606_0.jpg en la celda BS32
#   -> Imagen incrustada: IMG_20250908_125606_1.jpg en la celda BT32
#   -> Imagen incrustada: IMG_20250908_125606_2.jpg en la celda BU32
#   -> Imagen incrustada: IMG_20250908_125606_3.jpg en la celda BV32
#   -> Imagen incrustada: IMG_20250908_125607_4.jpg en la celda BW32
#   -> Imagen incrustada: IMG_20250908_122851_0.jpg en la celda BS33
#   -> Imagen incrustada: IMG_20250908_122851_1.jpg en la celda BT33
#   -> Imagen incrustada: IMG_20250908_122851_2.jpg en la celda BU33
#   -> Imagen incrustada: IMG_20250908_122851_3.jpg en la celda BV33
#   -> Imagen incrustada: IMG_20250908_122029_0.jpg en la celda BS34
#   -> Imagen incrustada: IMG_20250908_122029_1.jpg en la celda BT34
#   -> Imagen incrustada: IMG_20250908_122030_2.jpg en la celda BU34
#   -> Imagen incrustada: IMG_20250908_122030_3.jpg en la celda BV34
#   -> Imagen incrustada: IMG_20250908_122030_4.jpg en la celda BW34
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_112720_7229494867899711697.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_110212_7588029104782786993.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_110225_5809471491827463363.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_100525_3507142149922213190.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_100600_8065126119558529302.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_100647_8931474143868795796.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_100721_3466795413372826839.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_100747_4001284648417064983.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_093822_4489035804351183990.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_093834_7254679454263872231.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_093846_3811998521816047411.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_093858_8838203969282392588.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_094340_6247816725931856944.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_094422_6968041204608992776.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_072200_811840653657801516.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_072224_8467084239047481167.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_072236_32207056498368133.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_072249_7853759829707707244.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_070207_8590719016153954932.jpg
#   -> Imagen incrustada: IMG_20250908_195253_0.jpg en la celda BT40
#   -> Imagen incrustada: IMG_20250908_195253_1.jpg en la celda BU40
#   -> Imagen incrustada: IMG_20250908_195253_2.jpg en la celda BV40
#   -> Imagen incrustada: IMG_20250908_195253_3.jpg en la celda BW40
#   -> Imagen incrustada: IMG_20250908_195253_4.jpg en la celda BX40
#   -> Imagen incrustada: IMG_20250908_195253_5.jpg en la celda BY40
#   -> Imagen incrustada: JPEG_20250917_152631_1744619501207176905.jpg en la celda BS41
#   -> Imagen incrustada: JPEG_20250917_152801_5066268056351895926.jpg en la celda BT41
#   -> Imagen incrustada: JPEG_20250917_152830_4649248919748345057.jpg en la celda BU41
#   -> Imagen incrustada: JPEG_20250917_152851_7919412219570511202.jpg en la celda BV41
#   -> Imagen incrustada: JPEG_20250917_152921_2443029173621887444.jpg en la celda BW41
#   -> Imagen incrustada: JPEG_20250917_152933_163249808052302743.jpg en la celda BX41
#   -> Imagen incrustada: JPEG_20250917_120331_2420594018426239719.jpg en la celda BS42
#   -> Imagen incrustada: JPEG_20250917_120348_2274991856959695465.jpg en la celda BT42
#   -> Imagen incrustada: JPEG_20250917_120401_8573908679958550648.jpg en la celda BU42
#   -> Imagen incrustada: JPEG_20250917_120454_2017388544268333593.jpg en la celda BV42
#   -> Imagen incrustada: JPEG_20250917_120530_6262186013552257187.jpg en la celda BW42
#   -> Imagen incrustada: JPEG_20250917_115347_527085849220001786.jpg en la celda BS43
#   -> Imagen incrustada: JPEG_20250917_115651_2920419563309733432.jpg en la celda BT43
#   -> Imagen incrustada: JPEG_20250917_115704_7027715950508440833.jpg en la celda BU43
#   -> Imagen incrustada: JPEG_20250917_115743_6617919614339493352.jpg en la celda BV43
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250917_115821_1399176323767127841.jpg
#   -> Imagen incrustada: JPEG_20250917_115841_3887824417225158842.jpg en la celda BX43
#   -> Imagen incrustada: JPEG_20250917_114553_8371374826162410775.jpg en la celda BS44
#   -> Imagen incrustada: JPEG_20250917_115005_2389588481352946809.jpg en la celda BT44
#   -> Imagen incrustada: JPEG_20250917_115052_3445381153858753763.jpg en la celda BU44
#   -> Imagen incrustada: JPEG_20250917_115105_1684020774525615529.jpg en la celda BV44
#   -> Imagen incrustada: JPEG_20250917_115116_3430903843324838407.jpg en la celda BW44
#   -> Imagen incrustada: JPEG_20250917_113743_8330343408503388266.jpg en la celda BS45
#   -> Imagen incrustada: JPEG_20250917_113952_3229496401555080600.jpg en la celda BT45
#   -> Imagen incrustada: JPEG_20250917_114006_6613209352689604512.jpg en la celda BU45
#   -> Imagen incrustada: JPEG_20250917_114107_3376509494478052525.jpg en la celda BV45
#   -> Imagen incrustada: JPEG_20250917_112121_3030550950455840687.jpg en la celda BS46
#   -> Imagen incrustada: JPEG_20250917_112201_4499249432429427684.jpg en la celda BT46
#   -> Imagen incrustada: JPEG_20250917_112219_7702319617341359160.jpg en la celda BU46
#   -> Imagen incrustada: JPEG_20250917_112237_7726603334934486243.jpg en la celda BV46
#   -> Imagen incrustada: JPEG_20250917_112246_2237475291239287107.jpg en la celda BW46
#   -> Imagen incrustada: JPEG_20250917_112256_6104532961766872711.jpg en la celda BX46
#   -> Imagen incrustada: JPEG_20250917_112309_8250938238651080873.jpg en la celda BY46
#   -> Imagen incrustada: JPEG_20250917_112321_4849447244685410553.jpg en la celda BZ46
#   -> Imagen incrustada: JPEG_20250917_112336_2602729676449665305.jpg en la celda CA46
#   -> Imagen incrustada: JPEG_20250917_110946_3404538870181255312.jpg en la celda BS47
#   -> Imagen incrustada: JPEG_20250917_111001_1512096658716364743.jpg en la celda BT47
#   -> Imagen incrustada: JPEG_20250917_111024_8383297999506946953.jpg en la celda BU47
#   -> Imagen incrustada: JPEG_20250917_111037_4386576196585791293.jpg en la celda BV47
#   -> Imagen incrustada: JPEG_20250917_111050_3238503415271855838.jpg en la celda BW47
#   -> Imagen incrustada: JPEG_20250917_105745_6535049625331037881.jpg en la celda BS48
#   -> Imagen incrustada: JPEG_20250917_105757_8238216748631321091.jpg en la celda BT48
#   -> Imagen incrustada: JPEG_20250917_105813_7140297239385125550.jpg en la celda BU48
#   -> Imagen incrustada: JPEG_20250917_105834_7197118667456186334.jpg en la celda BV48
#   -> Imagen incrustada: JPEG_20250917_105842_2731293606698893823.jpg en la celda BW48
#   -> Imagen incrustada: JPEG_20250917_105859_8961534585637289729.jpg en la celda BX48
#   -> Imagen incrustada: JPEG_20250917_104634_4555630196998544544.jpg en la celda BS49
#   -> Imagen incrustada: JPEG_20250917_104645_3410950584783887050.jpg en la celda BT49
#   -> Imagen incrustada: JPEG_20250917_104710_4557043935656074602.jpg en la celda BU49
#   -> Imagen incrustada: JPEG_20250917_104723_8994035661635847364.jpg en la celda BV49
#   -> Imagen incrustada: JPEG_20250917_104742_8429932049223557467.jpg en la celda BW49
#   -> Imagen incrustada: JPEG_20250917_104758_4483151122974804118.jpg en la celda BX49
#   -> Imagen incrustada: JPEG_20250917_103301_2255052635857398084.jpg en la celda BS50
#   -> Imagen incrustada: JPEG_20250917_103402_4457903689002376995.jpg en la celda BT50
#   -> Imagen incrustada: JPEG_20250917_103414_7694466272157360404.jpg en la celda BU50
#   -> Imagen incrustada: JPEG_20250917_103728_5352391736993629168.jpg en la celda BV50
#   -> Imagen incrustada: JPEG_20250917_103747_8240527174201800291.jpg en la celda BW50
#   -> Imagen incrustada: JPEG_20250917_103811_8246148058064240350.jpg en la celda BX50
#   -> Imagen incrustada: JPEG_20250917_102647_8299774645342877285.jpg en la celda BS51
#   -> Imagen incrustada: JPEG_20250917_102752_2192325814616748444.jpg en la celda BT51
#   -> Imagen incrustada: JPEG_20250917_102815_4240690684280289334.jpg en la celda BU51
#   -> Imagen incrustada: JPEG_20250917_102827_299399395532826017.jpg en la celda BV51
#   -> Imagen incrustada: JPEG_20250917_102852_7630995914794708945.jpg en la celda BW51
#   -> Imagen incrustada: JPEG_20250917_101535_1230768213033416008.jpg en la celda BS52
#   -> Imagen incrustada: JPEG_20250917_101545_5621974360658027360.jpg en la celda BT52
#   -> Imagen incrustada: JPEG_20250917_101558_3129433922930626672.jpg en la celda BU52
#   -> Imagen incrustada: JPEG_20250917_101612_1709456140913279878.jpg en la celda BV52
#   -> Imagen incrustada: JPEG_20250917_101631_3216943598966578277.jpg en la celda BW52
#   -> Imagen incrustada: JPEG_20250917_095855_863310479695552396.jpg en la celda BS53
#   -> Imagen incrustada: JPEG_20250917_095914_6701862414059062160.jpg en la celda BT53
#   -> Imagen incrustada: JPEG_20250917_095936_4827323756156369719.jpg en la celda BU53
#   -> Imagen incrustada: JPEG_20250917_095953_6924516208807664186.jpg en la celda BV53
#   -> Imagen incrustada: JPEG_20250917_100117_4184792984220821548.jpg en la celda BW53
#   -> Imagen incrustada: JPEG_20250917_080212_868954227781143843.jpg en la celda BS54
#   -> Imagen incrustada: JPEG_20250917_080303_116016971314641476.jpg en la celda BT54
#   -> Imagen incrustada: JPEG_20250917_080332_121774368355761287.jpg en la celda BU54
#   -> Imagen incrustada: JPEG_20250917_080402_475426039132348511.jpg en la celda BV54
#   -> Imagen incrustada: JPEG_20250917_080418_4469414667219535448.jpg en la celda BW54
#   -> Imagen incrustada: JPEG_20250917_080453_5705990431158425502.jpg en la celda BX54
#   -> Imagen incrustada: JPEG_20250917_074931_9116669378369470177.jpg en la celda BS55
#   -> Imagen incrustada: JPEG_20250917_075000_1120487888150504461.jpg en la celda BT55
#   -> Imagen incrustada: JPEG_20250917_075017_6989500411330249640.jpg en la celda BU55
#   -> Imagen incrustada: JPEG_20250917_075038_1385268157924715813.jpg en la celda BV55
#   -> Imagen incrustada: JPEG_20250917_075050_445109925260737595.jpg en la celda BW55
#   -> Imagen incrustada: JPEG_20250917_075106_7792153262562825424.jpg en la celda BX55
#   -> Imagen incrustada: JPEG_20250916_153123_1918503351997792758.jpg en la celda BS56
#   -> Imagen incrustada: JPEG_20250916_153138_2412652526652271193.jpg en la celda BT56
#   -> Imagen incrustada: JPEG_20250916_153147_7996971181610032885.jpg en la celda BU56
#   -> Imagen incrustada: JPEG_20250916_153319_6670961614642959137.jpg en la celda BV56
#   -> Imagen incrustada: JPEG_20250916_153331_5204788252858283444.jpg en la celda BW56
#   -> Imagen incrustada: JPEG_20250916_152101_3813972471754867286.jpg en la celda BS57
#   -> Imagen incrustada: JPEG_20250916_152300_6827255098101368819.jpg en la celda BT57
#   -> Imagen incrustada: JPEG_20250916_152333_8056945582870247404.jpg en la celda BU57
#   -> Imagen incrustada: JPEG_20250916_152359_1150534399233289806.jpg en la celda BV57
#   -> Imagen incrustada: JPEG_20250916_152438_8460943030392295835.jpg en la celda BW57
#   -> Imagen incrustada: JPEG_20250916_152508_1137060277552640079.jpg en la celda BX57
#   -> Imagen incrustada: IMG_20250916_151632_0.jpg en la celda BS58
#   -> Imagen incrustada: IMG_20250916_151632_1.jpg en la celda BT58
#   -> Imagen incrustada: IMG_20250916_151632_2.jpg en la celda BU58
#   -> Imagen incrustada: JPEG_20250916_144551_3185524121103059806.jpg en la celda BS59
#   -> Imagen incrustada: JPEG_20250916_144604_9044592694643644916.jpg en la celda BT59
#   -> Imagen incrustada: JPEG_20250916_144632_3146601035555167454.jpg en la celda BU59
#   -> Imagen incrustada: JPEG_20250916_144704_6638611620408645975.jpg en la celda BV59
#   -> Imagen incrustada: JPEG_20250916_112715_2109176164064498968.jpg en la celda BS61
#   -> Imagen incrustada: JPEG_20250916_112727_4682684053422341405.jpg en la celda BT61
#   -> Imagen incrustada: JPEG_20250916_112750_4322255596088178955.jpg en la celda BU61
#   -> Imagen incrustada: JPEG_20250916_112942_5334895970034557207.jpg en la celda BV61
#   -> Imagen incrustada: JPEG_20250916_111859_3008121344291445400.jpg en la celda BS62
#   -> Imagen incrustada: JPEG_20250916_111910_5590244781436935216.jpg en la celda BT62
#   -> Imagen incrustada: JPEG_20250916_111921_6267211643046750123.jpg en la celda BU62
#   -> Imagen incrustada: JPEG_20250916_111943_2167812189559957750.jpg en la celda BV62
#   -> Imagen incrustada: JPEG_20250916_111954_1570169511154317323.jpg en la celda BW62
#   -> Imagen incrustada: JPEG_20250916_112005_7434297881446057555.jpg en la celda BX62
#   -> Imagen incrustada: JPEG_20250916_110850_8293652395522012094.jpg en la celda BS64
#   -> Imagen incrustada: JPEG_20250916_110948_8611802174700422766.jpg en la celda BT64
#   -> Imagen incrustada: JPEG_20250916_111002_3885231297167122275.jpg en la celda BU64
#   -> Imagen incrustada: JPEG_20250916_111027_5444909813965183754.jpg en la celda BV64
#   -> Imagen incrustada: JPEG_20250916_111049_8278072253293669347.jpg en la celda BW64
#   -> Imagen incrustada: JPEG_20250916_111132_9009083516088329698.jpg en la celda BX64
#   -> Imagen incrustada: JPEG_20250916_105900_3749144735506074880.jpg en la celda BS65
#   -> Imagen incrustada: JPEG_20250916_105919_5825611608784143461.jpg en la celda BT65
#   -> Imagen incrustada: JPEG_20250916_105940_5166410150707922384.jpg en la celda BU65
#   -> Imagen incrustada: JPEG_20250916_110031_573387656141485015.jpg en la celda BV65
#   -> Imagen incrustada: JPEG_20250916_104312_6135440849069757169.jpg en la celda BS66
#   -> Imagen incrustada: JPEG_20250916_104343_9060725673697768244.jpg en la celda BT66
#   -> Imagen incrustada: JPEG_20250916_104354_8761048206098600642.jpg en la celda BU66
#   -> Imagen incrustada: JPEG_20250916_104401_7252379617681325003.jpg en la celda BV66
#   -> Imagen incrustada: JPEG_20250916_104429_1318402251121089664.jpg en la celda BW66
#   -> Imagen incrustada: JPEG_20250916_103724_4851556613812098947.jpg en la celda BS67
#   -> Imagen incrustada: JPEG_20250916_103839_6689019272617686249.jpg en la celda BT67
#   -> Imagen incrustada: JPEG_20250916_103853_3796767997144514303.jpg en la celda BU67
#   -> Imagen incrustada: JPEG_20250916_103915_4325805754347388924.jpg en la celda BV67
#   -> Imagen incrustada: JPEG_20250916_103923_5970411637285342679.jpg en la celda BW67
#   -> Imagen incrustada: JPEG_20250916_102809_4360160605797555813.jpg en la celda BS68
#   -> Imagen incrustada: JPEG_20250916_102825_3487687522954874181.jpg en la celda BT68
#   -> Imagen incrustada: JPEG_20250916_102841_5720750921699588501.jpg en la celda BU68
#   -> Imagen incrustada: JPEG_20250916_102851_6325432557983577494.jpg en la celda BV68
#   -> Imagen incrustada: JPEG_20250916_102906_5687610359794887634.jpg en la celda BW68
#   -> Imagen incrustada: JPEG_20250916_102917_6696304646052440864.jpg en la celda BX68
#   -> Imagen incrustada: JPEG_20250916_101617_2728512696647977005.jpg en la celda BS69
#   -> Imagen incrustada: JPEG_20250916_101627_85375605402232331.jpg en la celda BT69
#   -> Imagen incrustada: JPEG_20250916_101713_542409207771790011.jpg en la celda BU69
#   -> Imagen incrustada: JPEG_20250916_101730_6981120542780446995.jpg en la celda BV69
#   -> Imagen incrustada: JPEG_20250916_101828_1153532360749133240.jpg en la celda BW69
#   -> Imagen incrustada: JPEG_20250916_100721_6298552062642773639.jpg en la celda BS70
#   -> Imagen incrustada: JPEG_20250916_100733_6575384977338099202.jpg en la celda BT70
#   -> Imagen incrustada: JPEG_20250916_100845_4819151711898008462.jpg en la celda BU70
#   -> Imagen incrustada: JPEG_20250916_100927_8430370198578132454.jpg en la celda BV70
#   -> Imagen incrustada: JPEG_20250916_100942_590085660884782551.jpg en la celda BW70
#   -> Imagen incrustada: JPEG_20250916_100950_3208326172414438403.jpg en la celda BX70
#   -> Imagen incrustada: JPEG_20250916_095906_4487271812130060021.jpg en la celda BS71
#   -> Imagen incrustada: JPEG_20250916_095922_8393590414058177649.jpg en la celda BT71
#   -> Imagen incrustada: JPEG_20250916_095941_7328101043915512516.jpg en la celda BU71
#   -> Imagen incrustada: JPEG_20250916_100022_7081063182367907709.jpg en la celda BV71
#   -> Imagen incrustada: JPEG_20250916_100034_4279327063874974096.jpg en la celda BW71
#   -> Imagen incrustada: JPEG_20250916_095021_1977830692817339206.jpg en la celda BS72
#   -> Imagen incrustada: JPEG_20250916_095030_4506191318591791747.jpg en la celda BT72
#   -> Imagen incrustada: JPEG_20250916_095046_8438637259240536299.jpg en la celda BU72
#   -> Imagen incrustada: JPEG_20250916_095059_2410916090882451345.jpg en la celda BV72
#   -> Imagen incrustada: JPEG_20250916_095112_8363378715628855410.jpg en la celda BW72
#   -> Imagen incrustada: JPEG_20250916_095232_4109838746184893074.jpg en la celda BX72
#   -> Imagen incrustada: JPEG_20250916_094644_3383976405256983050.jpg en la celda BS73
#   -> Imagen incrustada: JPEG_20250916_094658_4832523510886936376.jpg en la celda BT73
#   -> Imagen incrustada: JPEG_20250916_094708_7232212427773938900.jpg en la celda BU73
#   -> Imagen incrustada: JPEG_20250916_094720_6140644130169798724.jpg en la celda BV73
#   -> Imagen incrustada: JPEG_20250916_094735_7021582704307994365.jpg en la celda BW73
#   -> Imagen incrustada: JPEG_20250916_094007_6368269594654488186.jpg en la celda BS74
#   -> Imagen incrustada: JPEG_20250916_094017_7774624325545474570.jpg en la celda BT74
#   -> Imagen incrustada: JPEG_20250916_094038_9067769043303033537.jpg en la celda BU74
#   -> Imagen incrustada: JPEG_20250916_094056_4265253713899648843.jpg en la celda BV74
#   -> Imagen incrustada: JPEG_20250916_092219_843120071577040532.jpg en la celda BS75
#   -> Imagen incrustada: JPEG_20250916_092246_4179661401321805937.jpg en la celda BT75
#   -> Imagen incrustada: JPEG_20250916_092305_7001987421043061113.jpg en la celda BU75
#   -> Imagen incrustada: JPEG_20250916_092314_4257404466205912384.jpg en la celda BV75
#   -> Imagen incrustada: JPEG_20250916_092413_7771251383994279511.jpg en la celda BW75
#   -> Imagen incrustada: JPEG_20250916_090948_6983097293296670111.jpg en la celda BS76
#   -> Imagen incrustada: JPEG_20250916_091359_9009623443114530216.jpg en la celda BT76
#   -> Imagen incrustada: JPEG_20250916_091419_8999838772711589199.jpg en la celda BU76
#   -> Imagen incrustada: JPEG_20250916_091431_340828449349551233.jpg en la celda BV76
#   -> Imagen incrustada: JPEG_20250916_091443_421487835375570979.jpg en la celda BW76
#   -> Imagen incrustada: JPEG_20250916_090115_7472350043369769313.jpg en la celda BS77
#   -> Imagen incrustada: JPEG_20250916_090134_899272839135339698.jpg en la celda BT77
#   -> Imagen incrustada: JPEG_20250916_090147_3372494979883465256.jpg en la celda BU77
#   -> Imagen incrustada: JPEG_20250916_090227_3115831209829880089.jpg en la celda BV77
#   -> Imagen incrustada: JPEG_20250916_090318_3448307538366743794.jpg en la celda BW77
#   -> Imagen incrustada: JPEG_20250916_085140_3405039999665463586.jpg en la celda BS78
#   -> Imagen incrustada: JPEG_20250916_085157_9043362731158596631.jpg en la celda BT78
#   -> Imagen incrustada: JPEG_20250916_085213_4958868505087199209.jpg en la celda BU78
#   -> Imagen incrustada: JPEG_20250916_085227_3481875251731035048.jpg en la celda BV78
#   -> Imagen incrustada: JPEG_20250916_085317_6123077698088121916.jpg en la celda BW78
#   -> Imagen incrustada: JPEG_20250916_084332_802631651976541333.jpg en la celda BS79
#   -> Imagen incrustada: JPEG_20250916_084347_3715613020054810958.jpg en la celda BT79
#   -> Imagen incrustada: JPEG_20250916_084409_5907256247027891555.jpg en la celda BU79
#   -> Imagen incrustada: JPEG_20250916_084430_6736033551362682669.jpg en la celda BV79
#   -> Imagen incrustada: JPEG_20250916_084437_5919871070983076600.jpg en la celda BW79
#   -> Imagen incrustada: JPEG_20250916_084539_3873705312052615694.jpg en la celda BX79
#   -> Imagen incrustada: JPEG_20250916_083800_394971501137189400.jpg en la celda BS80
#   -> Imagen incrustada: JPEG_20250916_083855_4302535827706947787.jpg en la celda BT80
#   -> Imagen incrustada: JPEG_20250916_083910_9220493641255143025.jpg en la celda BU80
#   -> Imagen incrustada: JPEG_20250916_083920_7220939460727964540.jpg en la celda BV80
#   -> Imagen incrustada: JPEG_20250916_082606_7528917243626341371.jpg en la celda BS81
#   -> Imagen incrustada: JPEG_20250916_082734_4785442792742551222.jpg en la celda BT81
#   -> Imagen incrustada: JPEG_20250916_082748_1320369447760261777.jpg en la celda BU81
#   -> Imagen incrustada: JPEG_20250916_082759_4401268740398705139.jpg en la celda BV81
#   -> Imagen incrustada: JPEG_20250916_081522_9066828122559309148.jpg en la celda BS82
#   -> Imagen incrustada: JPEG_20250916_081530_4047126021184645385.jpg en la celda BT82
#   -> Imagen incrustada: JPEG_20250916_081551_9198593203957375132.jpg en la celda BU82
#   -> Imagen incrustada: JPEG_20250916_081656_4571628793849700272.jpg en la celda BV82
#   -> Imagen incrustada: JPEG_20250916_081736_7073638925627861555.jpg en la celda BW82
#   -> Imagen incrustada: JPEG_20250916_081802_280999619430668620.jpg en la celda BX82
#   -> Imagen incrustada: JPEG_20250916_081832_4171464931224066336.jpg en la celda BY82
#   -> Imagen incrustada: JPEG_20250916_080514_6793444667725414958.jpg en la celda BS83
#   -> Imagen incrustada: JPEG_20250916_080532_3415639250681826888.jpg en la celda BT83
#   -> Imagen incrustada: JPEG_20250916_080546_4419086800646686157.jpg en la celda BU83
#   -> Imagen incrustada: JPEG_20250916_080625_6052087859732159573.jpg en la celda BV83
#   -> Imagen incrustada: JPEG_20250916_080746_7346521026071399768.jpg en la celda BW83
#   -> Imagen incrustada: JPEG_20250916_075814_8490289706253845608.jpg en la celda BS84
#   -> Imagen incrustada: JPEG_20250916_075831_3923749857506144911.jpg en la celda BT84
#   -> Imagen incrustada: JPEG_20250916_075844_5997287956778995933.jpg en la celda BU84
#   -> Imagen incrustada: JPEG_20250916_080015_5380423369741470893.jpg en la celda BV84
#   -> Imagen incrustada: JPEG_20250916_080043_1699885863228998072.jpg en la celda BW84
#   -> Imagen incrustada: JPEG_20250916_080055_744053797043079881.jpg en la celda BX84
#   -> Imagen incrustada: JPEG_20250916_074709_4036776448313514940.jpg en la celda BS85
#   -> Imagen incrustada: JPEG_20250916_074757_2613648838991333237.jpg en la celda BT85
#   -> Imagen incrustada: JPEG_20250916_074846_418292395577327452.jpg en la celda BU85
#   -> Imagen incrustada: JPEG_20250916_074907_7877672103184857666.jpg en la celda BV85
#   -> Imagen incrustada: JPEG_20250916_074917_2104663315484267941.jpg en la celda BW85
#   -> Imagen incrustada: IMG_20250915_184854_0.jpg en la celda BS86
#   -> Imagen incrustada: IMG_20250915_184854_1.jpg en la celda BT86
#   -> Imagen incrustada: IMG_20250915_184854_2.jpg en la celda BU86
#   -> Imagen incrustada: IMG_20250915_184854_3.jpg en la celda BV86
#   -> Imagen incrustada: IMG_20250915_184854_4.jpg en la celda BW86
#   -> Imagen incrustada: IMG_20250915_184854_5.jpg en la celda BX86
#   -> Imagen incrustada: IMG_20250915_184854_6.jpg en la celda BY86
#   -> Imagen incrustada: IMG_20250915_184854_7.jpg en la celda BZ86
#   -> Imagen incrustada: IMG_20250915_184854_8.jpg en la celda CA86
#   -> Imagen incrustada: IMG_20250915_183214_0.jpg en la celda BS87
#   -> Imagen incrustada: IMG_20250915_183214_1.jpg en la celda BT87
#   -> Imagen incrustada: IMG_20250915_183214_2.jpg en la celda BU87
#   -> Imagen incrustada: IMG_20250915_183214_3.jpg en la celda BV87
#   -> Imagen incrustada: IMG_20250915_182651_0.jpg en la celda BS88
#   -> Imagen incrustada: IMG_20250915_182651_1.jpg en la celda BT88
#   -> Imagen incrustada: IMG_20250915_182651_2.jpg en la celda BU88
#   -> Imagen incrustada: IMG_20250915_181638_0.jpg en la celda BS89
#   -> Imagen incrustada: IMG_20250915_181638_1.jpg en la celda BT89
#   -> Imagen incrustada: IMG_20250915_180030_0.jpg en la celda BS90
#   -> Imagen incrustada: IMG_20250915_180030_1.jpg en la celda BT90
#   -> Imagen incrustada: IMG_20250915_180030_2.jpg en la celda BU90
#   -> Imagen incrustada: IMG_20250915_180030_3.jpg en la celda BV90
#   -> Imagen incrustada: IMG_20250915_172839_0.jpg en la celda BS91
#   -> Imagen incrustada: IMG_20250915_172839_1.jpg en la celda BT91
#   -> Imagen incrustada: IMG_20250915_172839_2.jpg en la celda BU91
#   -> Imagen incrustada: IMG_20250915_171046_0.jpg en la celda BS92
#   -> Imagen incrustada: IMG_20250915_171046_1.jpg en la celda BT92
#   -> Imagen incrustada: IMG_20250915_171046_2.jpg en la celda BU92
#   -> Imagen incrustada: IMG_20250915_171046_3.jpg en la celda BV92
#   -> Imagen incrustada: IMG_20250915_165215_0.jpg en la celda BS93
#   -> Imagen incrustada: IMG_20250915_165215_1.jpg en la celda BT93
#   -> Imagen incrustada: IMG_20250915_165215_2.jpg en la celda BU93
#   -> Imagen incrustada: IMG_20250915_165215_3.jpg en la celda BV93
#   -> Imagen incrustada: IMG_20250915_154833_0.jpg en la celda BS94
#   -> Imagen incrustada: IMG_20250915_154833_1.jpg en la celda BT94
#   -> Imagen incrustada: IMG_20250915_154834_2.jpg en la celda BU94
#   -> Imagen incrustada: IMG_20250915_154834_3.jpg en la celda BV94
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_154415_166225974158975279.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_154428_9079530563479248801.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_154440_817891315150114908.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_154453_5338210455252334125.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_154502_4202383510230288520.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_154517_9200909729836575271.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_152755_740839935934580320.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_152808_2832581576295920032.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_152819_5178155336507121729.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_152920_9127215018539980393.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_152946_8026723998071483709.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_151955_5135805032419212546.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_152015_6084908108096433610.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_152119_8104317883854240273.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_152140_2397955660096558200.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_151219_45355906035549324.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_151234_3831534509150481248.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_151255_7765355354496414483.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_151317_8357277743850416983.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_150217_1331852176802798665.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_150234_6683672757408752777.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_150244_8625402475759101680.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_150311_1301870228971723105.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_150320_3221168863138095423.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_150430_7315439705500835717.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_145717_3941546569037168772.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_145742_5343955846649746891.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_145754_6834893742330766348.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_145806_6870089545716708912.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_145826_7173239777059392318.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_145838_3389703866529349558.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_144516_8364394461406035802.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_144817_213764097542158015.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_144837_4807777450038421281.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250913_144851_7525680969352881439.jpg
# ...
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_083419_5160912830637594187.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_083437_7497730441424035287.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_082508_3351363355342600637.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_082518_6384822284895663107.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_082632_5914424329210359996.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_082710_5153859987891577632.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_081656_2432122210078191970.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_081736_8677306499865295787.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_081811_7313364565892451102.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_081823_7732532723741948629.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_081856_3021067034686540135.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_081120_1298985263490013493.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_081148_6240989248493362499.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_081203_3287109970365409629.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_081241_4284054611826287145.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_080236_767781284523666828.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_080314_1461999874650107588.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_080411_6044091636154043948.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_080514_4809514790849790790.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_075452_5400511972108010424.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_075522_6308203438033089190.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_075721_5303975834030325736.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_074958_1168088804490262333.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_075047_3358893540560578750.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_075116_5089052125900567750.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_075128_1521751918230945532.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_072051_4440677760486062808.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_072112_6397221088664257415.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_072140_5638561929083208339.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_072152_2912282878404651398.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_070723_6592292385444433086.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_070822_1028055003521840803.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_070858_2648313075801371003.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_071504_3594192751076827611.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_065819_4997108987318568354.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_065832_5510538342789925086.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_065859_99838862996267010.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_070104_7327031403299306346.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_065110_8143553673149873629.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_065122_5124720292395824923.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_065216_8910315892041965047.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_065348_5553499599789996163.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_063759_21762591110655275.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_064118_4179454655667723312.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_064134_2808173954305042962.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250909_064213_7406269760804386771.jpg
#   -> Imagen incrustada: IMG_20250908_213931_0.jpg en la celda BS182
#   -> Imagen incrustada: IMG_20250908_213931_1.jpg en la celda BT182
#   -> Imagen incrustada: IMG_20250908_213231_0.jpg en la celda BS183
#   -> Imagen incrustada: IMG_20250908_213231_1.jpg en la celda BT183
#   -> Imagen incrustada: IMG_20250908_213231_2.jpg en la celda BU183
#   -> Imagen incrustada: IMG_20250908_211009_0.jpg en la celda BS184
#   -> Imagen incrustada: IMG_20250908_211009_1.jpg en la celda BT184
#   -> Imagen incrustada: IMG_20250908_211009_2.jpg en la celda BU184
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_135117_7749079153358034877.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_135130_457672341649135895.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_134115_2342733842837251713.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_134124_8498382903328669655.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_134429_6593799742443069658.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_133617_3675133225002443549.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_133635_3394315743668251405.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_133651_7973242764941777187.jpg
#   -> Imagen incrustada: IMG_20250908_133053_0.jpg en la celda BS188
#   -> Imagen incrustada: IMG_20250908_133053_1.jpg en la celda BT188
#   -> Imagen incrustada: IMG_20250908_133053_2.jpg en la celda BU188
#   -> Imagen incrustada: IMG_20250908_133054_3.jpg en la celda BV188
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_133150_4461689700181560828.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_133212_7864214788445787088.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_133228_6711316216551751757.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_132205_3375586676343026023.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_132218_1550472402029601778.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_132241_6104245665123809811.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_132251_3689333305598792333.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_130743_6654708470999983521.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_130817_8507899591027461857.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_130836_7686240578942518024.jpg
#   -> Imagen incrustada: IMG_20250908_125606_0.jpg en la celda BS191
#   -> Imagen incrustada: IMG_20250908_125606_1.jpg en la celda BT191
#   -> Imagen incrustada: IMG_20250908_125606_2.jpg en la celda BU191
#   -> Imagen incrustada: IMG_20250908_125606_3.jpg en la celda BV191
#   -> Imagen incrustada: IMG_20250908_125607_4.jpg en la celda BW191
#   -> Imagen incrustada: IMG_20250908_122851_0.jpg en la celda BS192
#   -> Imagen incrustada: IMG_20250908_122851_1.jpg en la celda BT192
#   -> Imagen incrustada: IMG_20250908_122851_2.jpg en la celda BU192
#   -> Imagen incrustada: IMG_20250908_122851_3.jpg en la celda BV192
#   -> Imagen incrustada: IMG_20250908_122029_0.jpg en la celda BS193
#   -> Imagen incrustada: IMG_20250908_122029_1.jpg en la celda BT193
#   -> Imagen incrustada: IMG_20250908_122030_2.jpg en la celda BU193
#   -> Imagen incrustada: IMG_20250908_122030_3.jpg en la celda BV193
#   -> Imagen incrustada: IMG_20250908_122030_4.jpg en la celda BW193
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_112720_7229494867899711697.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_110212_7588029104782786993.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_110225_5809471491827463363.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_100525_3507142149922213190.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_100600_8065126119558529302.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_100647_8931474143868795796.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_100721_3466795413372826839.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_100747_4001284648417064983.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_093822_4489035804351183990.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_093834_7254679454263872231.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_093846_3811998521816047411.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_093858_8838203969282392588.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_094340_6247816725931856944.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_094422_6968041204608992776.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_072200_811840653657801516.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_072224_8467084239047481167.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_072236_32207056498368133.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_072249_7853759829707707244.jpg
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250908_070207_8590719016153954932.jpg
#   -> Imagen incrustada: IMG_20250908_195253_0.jpg en la celda BT199
#   -> Imagen incrustada: IMG_20250908_195253_1.jpg en la celda BU199
#   -> Imagen incrustada: IMG_20250908_195253_2.jpg en la celda BV199
#   -> Imagen incrustada: IMG_20250908_195253_3.jpg en la celda BW199
#   -> Imagen incrustada: IMG_20250908_195253_4.jpg en la celda BX199
#   -> Imagen incrustada: IMG_20250908_195253_5.jpg en la celda BY199
#   -> Imagen incrustada: JPEG_20250919_132934_3517783316450461124.jpg en la celda BS200
#   -> Imagen incrustada: JPEG_20250919_132941_8884018049319158214.jpg en la celda BT200
#   -> Imagen incrustada: JPEG_20250919_133848_8747657837768452406.jpg en la celda BU200
#   -> Imagen incrustada: JPEG_20250919_133949_8698992801770150912.jpg en la celda BV200
#   -> Imagen incrustada: JPEG_20250917_115032_8664507144120488475.jpg en la celda BS201
#   -> Imagen incrustada: JPEG_20250917_115144_6854224413466410914.jpg en la celda BT201
#   -> Imagen incrustada: JPEG_20250917_115156_1337351064045899074.jpg en la celda BU201
#   -> Imagen incrustada: JPEG_20250917_115224_8279111593156270102.jpg en la celda BV201
#   -> Archivo no encontrado: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3\JPEG_20250917_112528_8514050483002133982.jpg
#   -> Imagen incrustada: JPEG_20250917_112537_3359105391413848413.jpg en la celda BT202
#   -> Imagen incrustada: JPEG_20250917_111231_730924316410336736.jpg en la celda BS203
#   -> Imagen incrustada: JPEG_20250917_100248_4448394504260973645.jpg en la celda BS204
#   -> Imagen incrustada: JPEG_20250917_100259_3842934734556793110.jpg en la celda BT204
#   -> Imagen incrustada: JPEG_20250917_092538_5478462129402387566.jpg en la celda BS207
#   -> Imagen incrustada: JPEG_20250917_084449_8772050764113738488.jpg en la celda BS208
#   -> Imagen incrustada: JPEG_20250917_084457_2382269770403389161.jpg en la celda BT208
#   -> Imagen incrustada: JPEG_20250917_082809_2424213647346047231.jpg en la celda BS211
#   -> Imagen incrustada: JPEG_20250917_082832_4896869118666373203.jpg en la celda BT211
#
# Proceso de incrustación de imágenes finalizado.
#
# ¡Éxito! El archivo con las imágenes se ha guardado en: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\DATOS FINALES\proyecto_consolidado_con_fotos.xlsx

# %%
import pandas as pd
import openpyxl
import os
from openpyxl.drawing.image import Image

# --- CONFIGURACIÓN ---
ruta_archivo_entrada = r'C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\DATOS FINALES\proyecto_consolidado.xlsx'
ruta_carpeta_fotos = r'C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_3'
nombre_archivo_salida_con_fotos = 'proyecto_consolidado_con_fotos.xlsx'
ruta_completa_salida = os.path.join(os.path.dirname(ruta_archivo_entrada), nombre_archivo_salida_con_fotos)

# --- 1. LEER EL ARCHIVO CONSOLIDADO ---
print("Leyendo el archivo de Excel consolidado...")
df = pd.read_excel(ruta_archivo_entrada)

# Columnas de fotos
columnas_fotos = [col for col in df.columns if col.startswith('Foto')]
if not columnas_fotos:
    print("⚠️ No se encontraron columnas que empiecen con 'Foto'.")
    columnas_fotos = []

# --- 2. CREAR WORKBOOK ---
workbook = openpyxl.Workbook()
# Borro la hoja por defecto
workbook.remove(workbook.active)

# --- 3. CREAR UNA HOJA POR CADA CIRCUITO ---
if "Circuito" not in df.columns:
    print("⚠️ No existe la columna 'Circuito'. Se usará una sola hoja.")
    circuitos = {"General": df}
else:
    circuitos = {c: df[df["Circuito"] == c] for c in df["Circuito"].unique()}

for circuito, df_circ in circuitos.items():
    print(f"Creando hoja: {circuito}")
    sheet = workbook.create_sheet(title=str(circuito))

    # Encabezados
    for col_num, column_title in enumerate(df_circ.columns, 1):
        sheet.cell(row=1, column=col_num, value=column_title)

    # Datos + imágenes
    for row_idx, row in df_circ.iterrows():
        excel_row = list(df_circ.index).index(row_idx) + 2  # fila relativa dentro de esta hoja
        for col_num, cell_data in enumerate(row, 1):
            sheet.cell(row=excel_row, column=col_num, value=cell_data)

        # Procesar imágenes
        for foto_col in columnas_fotos:
            df_col_idx = df_circ.columns.get_loc(foto_col)
            excel_col = df_col_idx + 1
            nombre_foto = row[foto_col]

            if pd.notna(nombre_foto) and nombre_foto:
                ruta_foto = os.path.join(ruta_carpeta_fotos, nombre_foto)
                if os.path.exists(ruta_foto):
                    try:
                        img = Image(ruta_foto)
                        # Redimensionar a 100x100
                        img.width, img.height = 100, 100
                        coord = sheet.cell(row=excel_row, column=excel_col).coordinate
                        sheet.add_image(img, coord)
                    except Exception as e:
                        print(f"Error al incrustar {nombre_foto}: {e}")

    # --- 4. AJUSTAR ANCHO Y ALTO ---
    # Ajustar filas
    for row in sheet.iter_rows(min_row=2, max_row=sheet.max_row):
        sheet.row_dimensions[row[0].row].height = 75  # ~100px

    # Ajustar columnas
    for col in range(1, sheet.max_column + 1):
        sheet.column_dimensions[openpyxl.utils.get_column_letter(col)].width = 15  # ~100px

# --- 5. GUARDAR ---
try:
    workbook.save(ruta_completa_salida)
    print(f"\n✅ Archivo final guardado en: {ruta_completa_salida}")
except Exception as e:
    print(f"Error al guardar: {e}")
# Out:
# Leyendo el archivo de Excel consolidado...
# Creando hoja: SE CEL-Anda - EB2
# Creando hoja: EB1 - SE Santa Ana
# Creando hoja: na
#
# ✅ Archivo final guardado en: C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\DATOS FINALES\proyecto_consolidado_con_fotos.xlsx

# %%
import os
import shutil
from PIL import Image

# Ruta de la carpeta donde están las imágenes
carpeta = r"\\192.168.1.2\cenyt-proyectos\CEN-221_ANDA\2.INFOENTRADA\5. Inspeccion Redes\2025-09-15\ANDA-REDES\FOTOS"

# Carpeta de salida
carpeta_salida = r"\\192.168.1.2\cenyt-proyectos\CEN-221_ANDA\2.INFOENTRADA\5. Inspeccion Redes\2025-09-15\ANDA-REDES\Comprimidas"
os.makedirs(carpeta_salida, exist_ok=True)

# Tamaño máximo permitido en KB
limite_kb = 499

for archivo in os.listdir(carpeta):
    ruta = os.path.join(carpeta, archivo)

    # Verificar si es archivo y una imagen
    if os.path.isfile(ruta) and archivo.lower().endswith(('.jpg', '.jpeg', '.png')):
        tamano_kb = os.path.getsize(ruta) / 1024
        print(f"{archivo} -> {tamano_kb:.2f} KB")

        destino = os.path.join(carpeta_salida, archivo)

        if tamano_kb <= limite_kb:
            # Copiar directamente si no excede el límite
            shutil.copy2(ruta, destino)
            print(f"   → Copiada sin cambios ({tamano_kb:.2f} KB)")
        else:
            # Comprimir si excede el límite
            try:
                img = Image.open(ruta)

                if archivo.lower().endswith(('.jpg', '.jpeg')):
                    img.save(destino, optimize=True, quality=70)
                else:  # PNG → optimizar
                    img.save(destino, optimize=True)

                nuevo_tamano = os.path.getsize(destino) / 1024
                print(f"   → Comprimida: {nuevo_tamano:.2f} KB")

            except Exception as e:
                print(f"Error con {archivo}: {e}")
# Out:
# JPEG_20250913_111235_3250883094701253140.jpg -> 5855.35 KB
#    → Comprimida: 2294.34 KB
# JPEG_20250913_111221_5748109541630654790.jpg -> 3548.85 KB
#    → Comprimida: 1197.78 KB
# JPEG_20250913_111129_1359705467680473041.jpg -> 5964.25 KB
#    → Comprimida: 2363.53 KB
# JPEG_20250913_110338_5898135733816280796.jpg -> 4363.29 KB
#    → Comprimida: 1608.91 KB
# JPEG_20250913_110317_5329668562513601603.jpg -> 4577.55 KB
#    → Comprimida: 1708.54 KB
# JPEG_20250913_110254_960942644729947289.jpg -> 4716.71 KB
#    → Comprimida: 1775.04 KB
# JPEG_20250913_105537_2639509893398097532.jpg -> 4225.35 KB
#    → Comprimida: 1504.62 KB
# JPEG_20250913_105505_1820768442477964715.jpg -> 5417.43 KB
#    → Comprimida: 2113.77 KB
# JPEG_20250913_105433_6535652925998488234.jpg -> 5448.69 KB
#    → Comprimida: 2081.37 KB
# JPEG_20250913_104712_558431206323329141.jpg -> 3291.01 KB
#    → Comprimida: 1045.44 KB
# JPEG_20250913_104646_197311876332633740.jpg -> 3341.24 KB
#    → Comprimida: 1048.67 KB
# JPEG_20250913_104632_6748894105590554641.jpg -> 6226.90 KB
#    → Comprimida: 2457.13 KB
# JPEG_20250913_104526_4056977162872149785.jpg -> 3555.64 KB
#    → Comprimida: 1159.49 KB
# JPEG_20250913_103723_1707093523472111628.jpg -> 5126.11 KB
#    → Comprimida: 1973.28 KB
# JPEG_20250913_103633_4624914604501226350.jpg -> 4414.21 KB
#    → Comprimida: 1607.44 KB
# JPEG_20250913_103619_1088448004549677847.jpg -> 4454.53 KB
#    → Comprimida: 1628.84 KB
# JPEG_20250913_103606_2971287701104281848.jpg -> 2471.90 KB
#    → Comprimida: 622.79 KB
# JPEG_20250908_120514_7572046217761886382.jpg -> 5358.31 KB
#    → Comprimida: 2001.27 KB
# JPEG_20250908_120500_5153827927897211462.jpg -> 5559.34 KB
#    → Comprimida: 2173.54 KB
# JPEG_20250908_120445_2918768171131866121.jpg -> 5129.55 KB
#    → Comprimida: 1952.11 KB
# IMG_20250913_160628_2.jpg -> 4162.88 KB
#    → Comprimida: 1302.41 KB
# IMG_20250913_160628_1.jpg -> 3290.32 KB
#    → Comprimida: 729.60 KB
# IMG_20250913_160628_0.jpg -> 4203.63 KB
#    → Comprimida: 1321.65 KB
# IMG_20250913_155847_2.jpg -> 3548.47 KB
#    → Comprimida: 828.36 KB
# IMG_20250913_155847_1.jpg -> 3323.95 KB
#    → Comprimida: 778.21 KB
# IMG_20250913_155847_0.jpg -> 4048.46 KB
#    → Comprimida: 1203.16 KB
# IMG_20250913_155434_2.jpg -> 3413.94 KB
#    → Comprimida: 793.11 KB
# IMG_20250913_155434_1.jpg -> 3404.73 KB
#    → Comprimida: 826.17 KB
# IMG_20250913_155434_0.jpg -> 4149.02 KB
#    → Comprimida: 1228.96 KB
# IMG_20250913_154423_0.jpg -> 4003.84 KB
#    → Comprimida: 1168.74 KB
# IMG_20250913_154354_2.jpg -> 5340.85 KB
#    → Comprimida: 1873.45 KB
# IMG_20250913_154354_1.jpg -> 3567.35 KB
#    → Comprimida: 1128.13 KB
# IMG_20250913_154354_0.jpg -> 5212.80 KB
#    → Comprimida: 1807.17 KB
# IMG_20250913_152712_3.jpg -> 4346.10 KB
#    → Comprimida: 1367.48 KB
# IMG_20250913_152712_2.jpg -> 3918.92 KB
#    → Comprimida: 1021.59 KB
# IMG_20250913_152712_1.jpg -> 3748.38 KB
#    → Comprimida: 1202.39 KB
# IMG_20250913_152712_0.jpg -> 4154.16 KB
#    → Comprimida: 1170.80 KB
# IMG_20250913_152233_2.jpg -> 4234.21 KB
#    → Comprimida: 1218.67 KB
# IMG_20250913_152233_1.jpg -> 3720.18 KB
#    → Comprimida: 908.92 KB
# IMG_20250913_152233_0.jpg -> 4810.82 KB
#    → Comprimida: 1639.60 KB
# IMG_20250913_151349_2.jpg -> 4653.58 KB
#    → Comprimida: 1511.36 KB
# IMG_20250913_151349_1.jpg -> 3652.70 KB
#    → Comprimida: 894.22 KB
# IMG_20250913_151349_0.jpg -> 4149.15 KB
#    → Comprimida: 1237.46 KB
# IMG_20250913_150726_2.jpg -> 5040.10 KB
#    → Comprimida: 1716.54 KB
# IMG_20250913_150726_1.jpg -> 4189.13 KB
#    → Comprimida: 1210.50 KB
# IMG_20250913_150726_0.jpg -> 2426.42 KB
#    → Comprimida: 560.35 KB
# IMG_20250913_145848_1.jpg -> 3646.18 KB
#    → Comprimida: 947.68 KB
# IMG_20250913_145848_0.jpg -> 3691.42 KB
#    → Comprimida: 942.83 KB
# IMG_20250913_145758_1.jpg -> 3872.67 KB
#    → Comprimida: 999.96 KB
# IMG_20250913_145758_0.jpg -> 4665.09 KB
#    → Comprimida: 1484.56 KB
# IMG_20250913_145158_1.jpg -> 3613.90 KB
#    → Comprimida: 806.62 KB
# IMG_20250913_145158_0.jpg -> 3628.84 KB
#    → Comprimida: 894.75 KB
# IMG_20250913_145105_0.jpg -> 3035.67 KB
#    → Comprimida: 985.70 KB
# JPEG_20250913_112839_8183843523011196020.jpg -> 2541.60 KB
#    → Comprimida: 469.40 KB
# JPEG_20250913_112822_3370316098664628644.jpg -> 2075.48 KB
#    → Comprimida: 283.64 KB
# JPEG_20250913_112808_3363529334726761411.jpg -> 2426.74 KB
#    → Comprimida: 568.86 KB
# JPEG_20250913_112752_3644745619654636019.jpg -> 3660.50 KB
#    → Comprimida: 1181.89 KB
# JPEG_20250913_111255_7414575616740504203.jpg -> 5128.53 KB
#    → Comprimida: 1958.91 KB
# JPEG_20250904_102007_6754475670178049536.jpg -> 3373.21 KB
#    → Comprimida: 519.30 KB
# JPEG_20250904_102139_2714378637158105212.jpg -> 3740.79 KB
#    → Comprimida: 699.18 KB
# JPEG_20250904_102212_6787764060378165695.jpg -> 3960.58 KB
#    → Comprimida: 781.49 KB
# JPEG_20250904_102618_8508600331271901736.jpg -> 4643.28 KB
#    → Comprimida: 1075.03 KB
# JPEG_20250904_103722_1468900722159955655.jpg -> 3968.93 KB
#    → Comprimida: 773.29 KB
# JPEG_20250904_104701_6614820806790020965.jpg -> 4462.54 KB
#    → Comprimida: 999.90 KB
# JPEG_20250904_105003_3222316146968778122.jpg -> 5134.22 KB
#    → Comprimida: 1281.68 KB
# JPEG_20250904_104548_7691530317429893654.jpg -> 4163.71 KB
#    → Comprimida: 863.58 KB
# JPEG_20250904_104626_5068251037143720812.jpg -> 6164.91 KB
#    → Comprimida: 1685.93 KB
# JPEG_20250904_104649_8820714784092261519.jpg -> 3651.10 KB
#    → Comprimida: 652.82 KB
# IMG_20250913_145848_0 1.jpg -> 3691.42 KB
#    → Comprimida: 942.83 KB
# IMG_20250913_145848_1 1.jpg -> 3646.18 KB
#    → Comprimida: 947.68 KB
# IMG_20250913_150726_0 1.jpg -> 2426.42 KB
#    → Comprimida: 560.35 KB
# IMG_20250913_150726_1 1.jpg -> 4189.13 KB
#    → Comprimida: 1210.50 KB
# IMG_20250913_150726_2 1.jpg -> 5040.10 KB
#    → Comprimida: 1716.54 KB
# IMG_20250913_151349_0 1.jpg -> 4149.15 KB
#    → Comprimida: 1237.46 KB
# IMG_20250913_151349_1 1.jpg -> 3652.70 KB
#    → Comprimida: 894.22 KB
# IMG_20250913_151349_2 1.jpg -> 4653.58 KB
#    → Comprimida: 1511.36 KB
# IMG_20250913_152233_0 1.jpg -> 4810.82 KB
#    → Comprimida: 1639.60 KB
# IMG_20250913_152233_1 1.jpg -> 3720.18 KB
#    → Comprimida: 908.92 KB
# IMG_20250913_152233_2 1.jpg -> 4234.21 KB
#    → Comprimida: 1218.67 KB
# IMG_20250913_152712_0 1.jpg -> 4154.16 KB
#    → Comprimida: 1170.80 KB
# IMG_20250913_152712_1 1.jpg -> 3748.38 KB
#    → Comprimida: 1202.39 KB
# IMG_20250913_154423_0 1.jpg -> 4003.84 KB
#    → Comprimida: 1168.74 KB
# IMG_20250913_160628_0 1.jpg -> 4203.63 KB
#    → Comprimida: 1321.65 KB
# JPEG_20250908_120500_5153827927897211462 1.jpg -> 5559.34 KB
#    → Comprimida: 2173.54 KB
# JPEG_20250908_120514_7572046217761886382 1.jpg -> 5358.31 KB
#    → Comprimida: 2001.27 KB
# JPEG_20250913_103606_2971287701104281848 1.jpg -> 2471.90 KB
#    → Comprimida: 622.79 KB
# JPEG_20250913_103619_1088448004549677847 1.jpg -> 4454.53 KB
#    → Comprimida: 1628.84 KB
# JPEG_20250913_103723_1707093523472111628 1.jpg -> 5126.11 KB
#    → Comprimida: 1973.28 KB
# JPEG_20250913_104632_6748894105590554641 1.jpg -> 6226.90 KB
#    → Comprimida: 2457.13 KB
# JPEG_20250913_104712_558431206323329141 1.jpg -> 3291.01 KB
#    → Comprimida: 1045.44 KB
# JPEG_20250913_105537_2639509893398097532 1.jpg -> 4225.35 KB
#    → Comprimida: 1504.62 KB
# JPEG_20250913_110317_5329668562513601603 1.jpg -> 4577.55 KB
#    → Comprimida: 1708.54 KB
# JPEG_20250913_111129_1359705467680473041 1.jpg -> 5964.25 KB
#    → Comprimida: 2363.53 KB
# JPEG_20250913_112822_3370316098664628644 1.jpg -> 2075.48 KB
#    → Comprimida: 283.64 KB
# JPEG_20250916_084002_8580231296469750636.jpg -> 2505.52 KB
#    → Comprimida: 689.85 KB
# JPEG_20250916_084203_2320367866506183228.jpg -> 5540.73 KB
#    → Comprimida: 2167.14 KB
# JPEG_20250916_084604_3585461494321494798.jpg -> 4301.17 KB
#    → Comprimida: 1557.10 KB
# JPEG_20250916_085102_7017023352695267949.jpg -> 3693.00 KB
#    → Comprimida: 1257.29 KB
# JPEG_20250916_085355_7758792449890369181.jpg -> 5638.63 KB
#    → Comprimida: 2205.46 KB
# JPEG_20250916_091057_3745834678191352258.jpg -> 5401.68 KB
#    → Comprimida: 2090.44 KB
# JPEG_20250916_091920_3318655887746619267.jpg -> 6408.83 KB
#    → Comprimida: 2585.70 KB
# JPEG_20250916_092006_1581429621700165574.jpg -> 4529.99 KB
#    → Comprimida: 1661.62 KB
# JPEG_20250916_092429_1866630780099867115.jpg -> 6685.78 KB
#    → Comprimida: 2713.19 KB
# JPEG_20250916_093709_907106596327518636.jpg -> 4430.68 KB
#    → Comprimida: 1642.31 KB
# JPEG_20250916_093736_7602752358158031728.jpg -> 4944.42 KB
#    → Comprimida: 1855.24 KB
# JPEG_20250916_093746_421050134540274992.jpg -> 4864.45 KB
#    → Comprimida: 1864.25 KB
# JPEG_20250916_093804_1476026317747796236.jpg -> 2746.77 KB
#    → Comprimida: 766.33 KB
# JPEG_20250916_110557_7082497860198936966.jpg -> 4936.41 KB
#    → Comprimida: 1850.94 KB
# JPEG_20250916_110618_203552646599540277.jpg -> 5112.69 KB
#    → Comprimida: 1949.80 KB
# JPEG_20250916_110749_4550804896975837827.jpg -> 3009.49 KB
#    → Comprimida: 910.18 KB
# JPEG_20250916_111057_4634125956210260179.jpg -> 5319.28 KB
#    → Comprimida: 2044.30 KB
# JPEG_20250916_112806_8441633881098561491.jpg -> 6179.04 KB
#    → Comprimida: 2504.12 KB
# JPEG_20250916_112822_2579055152205827908.jpg -> 5995.40 KB
#    → Comprimida: 2423.98 KB
# JPEG_20250916_113059_6156142113666784755.jpg -> 4239.55 KB
#    → Comprimida: 1508.26 KB
# JPEG_20250916_145711_4487249970805090013.jpg -> 4244.46 KB
#    → Comprimida: 1508.41 KB
# JPEG_20250916_145933_7282014777990495200.jpg -> 3189.48 KB
#    → Comprimida: 988.80 KB
# JPEG_20250916_145954_8686850784954617436.jpg -> 3824.91 KB
#    → Comprimida: 1312.70 KB
# JPEG_20250916_151636_623446480408309215.jpg -> 5811.72 KB
#    → Comprimida: 2327.55 KB
# JPEG_20250916_151657_9006260886038713329.jpg -> 4763.07 KB
#    → Comprimida: 1799.69 KB
# JPEG_20250916_152113_2938422753194292709.jpg -> 5018.61 KB
#    → Comprimida: 1853.39 KB
# IMG_20250908_122029_0.jpg -> 3940.82 KB
#    → Comprimida: 1457.91 KB
# IMG_20250908_122029_1.jpg -> 2525.27 KB
#    → Comprimida: 459.91 KB
# IMG_20250908_122030_2.jpg -> 4154.45 KB
#    → Comprimida: 1493.80 KB
# IMG_20250908_122030_3.jpg -> 3048.52 KB
#    → Comprimida: 1032.19 KB
# IMG_20250908_122030_4.jpg -> 2374.03 KB
#    → Comprimida: 752.61 KB
# IMG_20250908_122851_0.jpg -> 2353.28 KB
#    → Comprimida: 561.99 KB
# IMG_20250908_122851_1.jpg -> 4381.37 KB
#    → Comprimida: 1546.36 KB
# IMG_20250908_122851_2.jpg -> 4346.25 KB
#    → Comprimida: 1516.95 KB
# IMG_20250908_122851_3.jpg -> 3045.84 KB
#    → Comprimida: 839.39 KB
# IMG_20250908_125606_0.jpg -> 2251.44 KB
#    → Comprimida: 485.78 KB
# IMG_20250908_125606_1.jpg -> 2988.88 KB
#    → Comprimida: 1034.34 KB
# IMG_20250908_125606_2.jpg -> 4099.62 KB
#    → Comprimida: 1475.86 KB
# IMG_20250908_125606_3.jpg -> 2282.48 KB
#    → Comprimida: 433.94 KB
# IMG_20250908_125607_4.jpg -> 4269.32 KB
#    → Comprimida: 1697.11 KB
# IMG_20250908_133053_0.jpg -> 3836.06 KB
#    → Comprimida: 1522.23 KB
# IMG_20250908_133053_1.jpg -> 3603.03 KB
#    → Comprimida: 1274.76 KB
# IMG_20250908_133053_2.jpg -> 2098.97 KB
#    → Comprimida: 497.64 KB
# IMG_20250908_133054_3.jpg -> 3244.58 KB
#    → Comprimida: 1278.02 KB
# IMG_20250908_195253_0.jpg -> 447.20 KB
#    → Copiada sin cambios (447.20 KB)
# IMG_20250908_195253_1.jpg -> 508.30 KB
#    → Comprimida: 501.24 KB
# IMG_20250908_195253_2.jpg -> 499.75 KB
#    → Comprimida: 494.97 KB
# IMG_20250908_195253_3.jpg -> 457.86 KB
#    → Copiada sin cambios (457.86 KB)
# IMG_20250908_195253_4.jpg -> 682.29 KB
#    → Comprimida: 677.96 KB
# IMG_20250908_195253_5.jpg -> 817.68 KB
#    → Comprimida: 825.34 KB
# IMG_20250908_211009_0.jpg -> 249.85 KB
#    → Copiada sin cambios (249.85 KB)
# IMG_20250908_211009_1.jpg -> 397.22 KB
#    → Copiada sin cambios (397.22 KB)
# IMG_20250908_211009_2.jpg -> 375.54 KB
#    → Copiada sin cambios (375.54 KB)
# IMG_20250908_213231_0.jpg -> 387.67 KB
#    → Copiada sin cambios (387.67 KB)
# IMG_20250908_213231_1.jpg -> 154.51 KB
#    → Copiada sin cambios (154.51 KB)
# IMG_20250908_213931_0.jpg -> 170.67 KB
#    → Copiada sin cambios (170.67 KB)
# IMG_20250908_213931_1.jpg -> 251.97 KB
#    → Copiada sin cambios (251.97 KB)
# IMG_20250909_182742_0.jpg -> 277.00 KB
#    → Copiada sin cambios (277.00 KB)
# IMG_20250909_182742_1.jpg -> 130.08 KB
#    → Copiada sin cambios (130.08 KB)
# IMG_20250909_183855_0.jpg -> 105.72 KB
#    → Copiada sin cambios (105.72 KB)
# IMG_20250909_183855_1.jpg -> 84.77 KB
#    → Copiada sin cambios (84.77 KB)
# IMG_20250909_183855_2.jpg -> 197.22 KB
#    → Copiada sin cambios (197.22 KB)
# IMG_20250915_154833_0 (1).jpg -> 388.73 KB
#    → Copiada sin cambios (388.73 KB)
# IMG_20250915_154833_0.jpg -> 388.73 KB
#    → Copiada sin cambios (388.73 KB)
# IMG_20250915_154833_1.jpg -> 419.37 KB
#    → Copiada sin cambios (419.37 KB)
# IMG_20250915_154834_2.jpg -> 475.83 KB
#    → Copiada sin cambios (475.83 KB)
# IMG_20250915_154834_3.jpg -> 669.07 KB
#    → Comprimida: 282.86 KB
# IMG_20250915_165215_0.jpg -> 432.60 KB
#    → Copiada sin cambios (432.60 KB)
# IMG_20250915_165215_1.jpg -> 503.00 KB
#    → Comprimida: 214.30 KB
# IMG_20250915_165215_2.jpg -> 630.83 KB
#    → Comprimida: 255.22 KB
# IMG_20250915_165215_3.jpg -> 511.06 KB
#    → Comprimida: 212.07 KB
# IMG_20250915_171046_0.jpg -> 327.63 KB
#    → Copiada sin cambios (327.63 KB)
# IMG_20250915_171046_1.jpg -> 377.42 KB
#    → Copiada sin cambios (377.42 KB)
# IMG_20250915_171046_2.jpg -> 616.21 KB
#    → Comprimida: 242.87 KB
# IMG_20250915_171046_3.jpg -> 256.22 KB
#    → Copiada sin cambios (256.22 KB)
# IMG_20250915_172839_0.jpg -> 327.63 KB
#    → Copiada sin cambios (327.63 KB)
# IMG_20250915_172839_1.jpg -> 616.21 KB
#    → Comprimida: 242.87 KB
# IMG_20250915_172839_2.jpg -> 377.42 KB
#    → Copiada sin cambios (377.42 KB)
# IMG_20250915_180030_0.jpg -> 805.26 KB
#    → Comprimida: 328.33 KB
# IMG_20250915_180030_1.jpg -> 590.19 KB
#    → Comprimida: 259.17 KB
# IMG_20250915_180030_2.jpg -> 434.29 KB
#    → Copiada sin cambios (434.29 KB)
# IMG_20250915_180030_3.jpg -> 662.53 KB
#    → Comprimida: 296.31 KB
# IMG_20250915_181638_0.jpg -> 335.93 KB
#    → Copiada sin cambios (335.93 KB)
# IMG_20250915_181638_1.jpg -> 459.23 KB
#    → Copiada sin cambios (459.23 KB)
# IMG_20250915_182651_0.jpg -> 494.36 KB
#    → Copiada sin cambios (494.36 KB)
# IMG_20250915_182651_1.jpg -> 494.36 KB
#    → Copiada sin cambios (494.36 KB)
# IMG_20250915_182651_2.jpg -> 494.36 KB
#    → Copiada sin cambios (494.36 KB)
# IMG_20250915_183214_0.jpg -> 699.82 KB
#    → Comprimida: 317.08 KB
# IMG_20250915_183214_1.jpg -> 612.91 KB
#    → Comprimida: 265.83 KB
# IMG_20250915_183214_2.jpg -> 786.98 KB
#    → Comprimida: 358.11 KB
# IMG_20250915_183214_3.jpg -> 584.49 KB
#    → Comprimida: 250.41 KB
# IMG_20250915_184854_0.jpg -> 562.88 KB
#    → Comprimida: 242.94 KB
# IMG_20250915_184854_1.jpg -> 564.95 KB
#    → Comprimida: 236.88 KB
# IMG_20250915_184854_2.jpg -> 567.72 KB
#    → Comprimida: 237.72 KB
# IMG_20250915_184854_3.jpg -> 581.07 KB
#    → Comprimida: 242.52 KB
# IMG_20250915_184854_4.jpg -> 510.58 KB
#    → Comprimida: 208.79 KB
# IMG_20250915_184854_5.jpg -> 98.10 KB
#    → Copiada sin cambios (98.10 KB)
# IMG_20250915_184854_6.jpg -> 3609.33 KB
#    → Comprimida: 1362.01 KB
# IMG_20250915_184854_7.jpg -> 3541.88 KB
#    → Comprimida: 1325.48 KB
# IMG_20250915_184854_8.jpg -> 3489.82 KB
#    → Comprimida: 1458.41 KB
# JPEG_20250916_094007_6368269594654488186.jpg -> 3726.43 KB
#    → Comprimida: 914.47 KB
# JPEG_20250916_094017_7774624325545474570.jpg -> 3722.91 KB
#    → Comprimida: 1351.02 KB
# JPEG_20250916_094038_9067769043303033537.jpg -> 2520.42 KB
#    → Comprimida: 562.14 KB
# JPEG_20250916_094056_4265253713899648843.jpg -> 4851.61 KB
#    → Comprimida: 1929.92 KB
# JPEG_20250916_094644_3383976405256983050.jpg -> 3460.35 KB
#    → Comprimida: 1194.80 KB
# JPEG_20250916_094658_4832523510886936376.jpg -> 2116.86 KB
#    → Comprimida: 502.46 KB
# JPEG_20250916_094708_7232212427773938900.jpg -> 4403.34 KB
#    → Comprimida: 1532.49 KB
# JPEG_20250916_085213_4958868505087199209.jpg -> 3311.86 KB
#    → Comprimida: 1016.39 KB
# JPEG_20250916_094720_6140644130169798724.jpg -> 3449.94 KB
#    → Comprimida: 832.67 KB
# JPEG_20250916_094735_7021582704307994365.jpg -> 3737.02 KB
#    → Comprimida: 1283.46 KB
# JPEG_20250916_095021_1977830692817339206.jpg -> 3518.37 KB
#    → Comprimida: 1195.38 KB
# JPEG_20250916_095030_4506191318591791747.jpg -> 2533.65 KB
#    → Comprimida: 396.45 KB
# JPEG_20250916_095046_8438637259240536299.jpg -> 4274.84 KB
#    → Comprimida: 1440.41 KB
# JPEG_20250916_095059_2410916090882451345.jpg -> 2954.09 KB
#    → Comprimida: 964.92 KB
# JPEG_20250916_095112_8363378715628855410.jpg -> 2177.92 KB
#    → Comprimida: 461.98 KB
# JPEG_20250916_095232_4109838746184893074.jpg -> 3173.98 KB
#    → Comprimida: 730.16 KB
# JPEG_20250916_095906_4487271812130060021.jpg -> 3363.01 KB
#    → Comprimida: 849.14 KB
# JPEG_20250916_095922_8393590414058177649.jpg -> 3577.49 KB
#    → Comprimida: 1163.30 KB
# JPEG_20250916_095941_7328101043915512516.jpg -> 1916.84 KB
#    → Comprimida: 318.57 KB
# JPEG_20250916_100022_7081063182367907709.jpg -> 5373.88 KB
#    → Comprimida: 2344.70 KB
# JPEG_20250916_100034_4279327063874974096.jpg -> 3936.08 KB
#    → Comprimida: 1364.22 KB
# JPEG_20250916_100721_6298552062642773639.jpg -> 4942.23 KB
#    → Comprimida: 1815.88 KB
# JPEG_20250916_100733_6575384977338099202.jpg -> 2360.97 KB
#    → Comprimida: 459.48 KB
# JPEG_20250916_100845_4819151711898008462.jpg -> 3482.23 KB
#    → Comprimida: 869.11 KB
# JPEG_20250916_100927_8430370198578132454.jpg -> 4687.01 KB
#    → Comprimida: 1687.80 KB
# JPEG_20250916_100942_590085660884782551.jpg -> 4546.48 KB
#    → Comprimida: 1705.35 KB
# JPEG_20250916_100950_3208326172414438403.jpg -> 2407.12 KB
#    → Comprimida: 433.07 KB
# JPEG_20250916_101617_2728512696647977005.jpg -> 5085.31 KB
#    → Comprimida: 1916.70 KB
# JPEG_20250916_101627_85375605402232331.jpg -> 3723.65 KB
#    → Comprimida: 1416.07 KB
# JPEG_20250916_101713_542409207771790011.jpg -> 2241.14 KB
#    → Comprimida: 433.98 KB
# JPEG_20250916_101730_6981120542780446995.jpg -> 4857.61 KB
#    → Comprimida: 1790.83 KB
# JPEG_20250916_101828_1153532360749133240.jpg -> 3190.70 KB
#    → Comprimida: 763.49 KB
# JPEG_20250916_102809_4360160605797555813.jpg -> 3108.75 KB
#    → Comprimida: 727.62 KB
# JPEG_20250916_102825_3487687522954874181.jpg -> 3773.76 KB
#    → Comprimida: 1272.52 KB
# JPEG_20250916_102841_5720750921699588501.jpg -> 2577.77 KB
#    → Comprimida: 489.18 KB
# JPEG_20250916_102851_6325432557983577494.jpg -> 4442.19 KB
#    → Comprimida: 1779.79 KB
# JPEG_20250916_102906_5687610359794887634.jpg -> 3311.31 KB
#    → Comprimida: 1145.82 KB
# JPEG_20250916_102917_6696304646052440864.jpg -> 4742.00 KB
#    → Comprimida: 1797.54 KB
# JPEG_20250916_103724_4851556613812098947.jpg -> 2648.34 KB
#    → Comprimida: 564.00 KB
# JPEG_20250916_103839_6689019272617686249.jpg -> 3008.75 KB
#    → Comprimida: 745.96 KB
# JPEG_20250916_103853_3796767997144514303.jpg -> 3785.92 KB
#    → Comprimida: 1319.57 KB
# JPEG_20250916_103915_4325805754347388924.jpg -> 4041.10 KB
#    → Comprimida: 1419.67 KB
# JPEG_20250916_103923_5970411637285342679.jpg -> 2453.60 KB
#    → Comprimida: 749.05 KB
# JPEG_20250916_104312_6135440849069757169.jpg -> 3087.82 KB
#    → Comprimida: 1090.91 KB
# JPEG_20250916_104343_9060725673697768244.jpg -> 4186.62 KB
#    → Comprimida: 1506.12 KB
# JPEG_20250916_104354_8761048206098600642.jpg -> 2838.04 KB
#    → Comprimida: 591.52 KB
# JPEG_20250916_104401_7252379617681325003.jpg -> 2225.63 KB
#    → Comprimida: 409.20 KB
# JPEG_20250916_104429_1318402251121089664.jpg -> 3405.32 KB
#    → Comprimida: 936.14 KB
# JPEG_20250916_105900_3749144735506074880.jpg -> 4528.95 KB
#    → Comprimida: 1602.65 KB
# JPEG_20250916_105919_5825611608784143461.jpg -> 2661.17 KB
#    → Comprimida: 533.36 KB
# JPEG_20250916_105940_5166410150707922384.jpg -> 3093.94 KB
#    → Comprimida: 1084.81 KB
# JPEG_20250916_110031_573387656141485015.jpg -> 3572.96 KB
#    → Comprimida: 895.35 KB
# JPEG_20250916_110850_8293652395522012094.jpg -> 3162.96 KB
#    → Comprimida: 1362.57 KB
# JPEG_20250916_110948_8611802174700422766.jpg -> 3422.89 KB
#    → Comprimida: 1192.45 KB
# JPEG_20250916_111002_3885231297167122275.jpg -> 3885.56 KB
#    → Comprimida: 1390.88 KB
# JPEG_20250916_111027_5444909813965183754.jpg -> 3735.36 KB
#    → Comprimida: 1267.09 KB
# JPEG_20250916_111049_8278072253293669347.jpg -> 2470.54 KB
#    → Comprimida: 408.01 KB
# JPEG_20250916_111132_9009083516088329698.jpg -> 3169.25 KB
#    → Comprimida: 730.22 KB
# JPEG_20250916_111859_3008121344291445400.jpg -> 4094.74 KB
#    → Comprimida: 1722.61 KB
# JPEG_20250916_111910_5590244781436935216.jpg -> 3823.84 KB
#    → Comprimida: 1568.10 KB
# JPEG_20250916_111921_6267211643046750123.jpg -> 2630.65 KB
#    → Comprimida: 734.38 KB
# JPEG_20250916_111943_2167812189559957750.jpg -> 5122.15 KB
#    → Comprimida: 1917.28 KB
# JPEG_20250916_111954_1570169511154317323.jpg -> 2411.22 KB
#    → Comprimida: 429.13 KB
# JPEG_20250916_112005_7434297881446057555.jpg -> 3753.71 KB
#    → Comprimida: 947.35 KB
# JPEG_20250916_112715_2109176164064498968.jpg -> 3820.96 KB
#    → Comprimida: 1312.52 KB
# JPEG_20250916_112727_4682684053422341405.jpg -> 2174.60 KB
#    → Comprimida: 452.14 KB
# JPEG_20250916_112750_4322255596088178955.jpg -> 2874.34 KB
#    → Comprimida: 988.00 KB
# JPEG_20250916_112942_5334895970034557207.jpg -> 3123.27 KB
#    → Comprimida: 689.42 KB
# JPEG_20250916_144551_3185524121103059806.jpg -> 2909.67 KB
#    → Comprimida: 689.47 KB
# JPEG_20250916_144604_9044592694643644916.jpg -> 4048.24 KB
#    → Comprimida: 1441.59 KB
# JPEG_20250916_144632_3146601035555167454.jpg -> 2569.19 KB
#    → Comprimida: 579.16 KB
# JPEG_20250916_144704_6638611620408645975.jpg -> 4522.47 KB
#    → Comprimida: 1596.98 KB
# JPEG_20250916_152101_3813972471754867286.jpg -> 3766.05 KB
#    → Comprimida: 1187.26 KB
# JPEG_20250916_152300_6827255098101368819.jpg -> 2886.87 KB
#    → Comprimida: 940.21 KB
# JPEG_20250916_152333_8056945582870247404.jpg -> 4040.33 KB
#    → Comprimida: 1579.24 KB
# JPEG_20250916_152359_1150534399233289806.jpg -> 2345.26 KB
#    → Comprimida: 485.85 KB
# JPEG_20250916_152438_8460943030392295835.jpg -> 4014.95 KB
#    → Comprimida: 1072.25 KB
# JPEG_20250916_152508_1137060277552640079.jpg -> 3564.16 KB
#    → Comprimida: 1194.11 KB
# JPEG_20250916_153123_1918503351997792758.jpg -> 3780.36 KB
#    → Comprimida: 1453.05 KB
# JPEG_20250916_153138_2412652526652271193.jpg -> 2838.67 KB
#    → Comprimida: 767.89 KB
# JPEG_20250916_153147_7996971181610032885.jpg -> 4380.08 KB
#    → Comprimida: 1623.88 KB
# JPEG_20250916_153319_6670961614642959137.jpg -> 3795.01 KB
#    → Comprimida: 991.22 KB
# JPEG_20250916_153331_5204788252858283444.jpg -> 5813.42 KB
#    → Comprimida: 2325.25 KB
# JPEG_20250917_074931_9116669378369470177.jpg -> 3012.59 KB
#    → Comprimida: 750.51 KB
# JPEG_20250917_075000_1120487888150504461.jpg -> 3696.60 KB
#    → Comprimida: 1333.06 KB
# JPEG_20250917_075017_6989500411330249640.jpg -> 2283.94 KB
#    → Comprimida: 481.29 KB
# JPEG_20250917_075038_1385268157924715813.jpg -> 4735.32 KB
#    → Comprimida: 1732.75 KB
# JPEG_20250917_075050_445109925260737595.jpg -> 2507.61 KB
#    → Comprimida: 695.87 KB
# JPEG_20250917_075106_7792153262562825424.jpg -> 4620.02 KB
#    → Comprimida: 1933.62 KB
# JPEG_20250917_080212_868954227781143843.jpg -> 4162.64 KB
#    → Comprimida: 1025.61 KB
# JPEG_20250917_080303_116016971314641476.jpg -> 5668.75 KB
#    → Comprimida: 2316.74 KB
# JPEG_20250917_080332_121774368355761287.jpg -> 3610.20 KB
#    → Comprimida: 1219.93 KB
# JPEG_20250917_080402_475426039132348511.jpg -> 3706.84 KB
#    → Comprimida: 1261.06 KB
# JPEG_20250917_080418_4469414667219535448.jpg -> 2357.44 KB
#    → Comprimida: 515.19 KB
# JPEG_20250917_080453_5705990431158425502.jpg -> 6174.29 KB
#    → Comprimida: 2539.27 KB
# JPEG_20250917_095855_863310479695552396.jpg -> 3321.33 KB
#    → Comprimida: 1033.73 KB
# JPEG_20250917_095914_6701862414059062160.jpg -> 4524.69 KB
#    → Comprimida: 1659.02 KB
# JPEG_20250917_095936_4827323756156369719.jpg -> 2829.80 KB
#    → Comprimida: 1003.96 KB
# JPEG_20250917_095953_6924516208807664186.jpg -> 2527.96 KB
#    → Comprimida: 591.78 KB
# JPEG_20250917_100117_4184792984220821548.jpg -> 4163.97 KB
#    → Comprimida: 1075.23 KB
# JPEG_20250917_101535_1230768213033416008.jpg -> 3360.47 KB
#    → Comprimida: 799.02 KB
# JPEG_20250917_101545_5621974360658027360.jpg -> 5590.97 KB
#    → Comprimida: 2329.40 KB
# JPEG_20250917_101558_3129433922930626672.jpg -> 4489.81 KB
#    → Comprimida: 1662.48 KB
# JPEG_20250917_101612_1709456140913279878.jpg -> 4615.57 KB
#    → Comprimida: 1721.88 KB
# JPEG_20250917_101631_3216943598966578277.jpg -> 2768.35 KB
#    → Comprimida: 785.02 KB
# JPEG_20250917_102647_8299774645342877285.jpg -> 3649.52 KB
#    → Comprimida: 1030.46 KB
# JPEG_20250917_102752_2192325814616748444.jpg -> 3540.89 KB
#    → Comprimida: 892.61 KB
# JPEG_20250917_102815_4240690684280289334.jpg -> 4045.67 KB
#    → Comprimida: 1464.43 KB
# JPEG_20250917_102827_299399395532826017.jpg -> 2371.50 KB
#    → Comprimida: 456.71 KB
# JPEG_20250917_102852_7630995914794708945.jpg -> 3416.64 KB
#    → Comprimida: 1213.90 KB
# JPEG_20250917_103301_2255052635857398084.jpg -> 3263.41 KB
#    → Comprimida: 1282.08 KB
# JPEG_20250917_103402_4457903689002376995.jpg -> 4534.55 KB
#    → Comprimida: 1731.08 KB
# JPEG_20250917_103414_7694466272157360404.jpg -> 2726.68 KB
#    → Comprimida: 825.33 KB
# JPEG_20250917_103728_5352391736993629168.jpg -> 4180.82 KB
#    → Comprimida: 1043.54 KB
# JPEG_20250917_103747_8240527174201800291.jpg -> 6264.19 KB
#    → Comprimida: 2553.88 KB
# JPEG_20250917_103811_8246148058064240350.jpg -> 2132.52 KB
#    → Comprimida: 542.39 KB
# JPEG_20250917_104634_4555630196998544544.jpg -> 3413.92 KB
#    → Comprimida: 812.47 KB
# JPEG_20250917_104645_3410950584783887050.jpg -> 3623.07 KB
#    → Comprimida: 1434.73 KB
# JPEG_20250917_104710_4557043935656074602.jpg -> 3975.04 KB
#    → Comprimida: 1401.22 KB
# JPEG_20250917_104723_8994035661635847364.jpg -> 2427.71 KB
#    → Comprimida: 568.79 KB
# JPEG_20250917_104742_8429932049223557467.jpg -> 4318.98 KB
#    → Comprimida: 1599.27 KB
# JPEG_20250917_104758_4483151122974804118.jpg -> 2507.42 KB
#    → Comprimida: 785.76 KB
# JPEG_20250917_105745_6535049625331037881.jpg -> 3345.65 KB
#    → Comprimida: 835.80 KB
# JPEG_20250917_105757_8238216748631321091.jpg -> 4317.04 KB
#    → Comprimida: 1757.14 KB
# JPEG_20250917_105813_7140297239385125550.jpg -> 3433.90 KB
#    → Comprimida: 1193.36 KB
# JPEG_20250917_105834_7197118667456186334.jpg -> 4423.91 KB
#    → Comprimida: 1663.13 KB
# JPEG_20250917_105842_2731293606698893823.jpg -> 2319.62 KB
#    → Comprimida: 581.50 KB
# JPEG_20250917_105859_8961534585637289729.jpg -> 3334.55 KB
#    → Comprimida: 1160.69 KB
# JPEG_20250917_110946_3404538870181255312.jpg -> 3470.99 KB
#    → Comprimida: 946.12 KB
# JPEG_20250917_111001_1512096658716364743.jpg -> 5403.28 KB
#    → Comprimida: 2324.47 KB
# JPEG_20250917_111024_8383297999506946953.jpg -> 5307.35 KB
#    → Comprimida: 2230.88 KB
# JPEG_20250917_111037_4386576196585791293.jpg -> 4057.50 KB
#    → Comprimida: 1443.63 KB
# JPEG_20250917_111050_3238503415271855838.jpg -> 2289.28 KB
#    → Comprimida: 589.61 KB
# JPEG_20250917_112121_3030550950455840687.jpg -> 3106.46 KB
#    → Comprimida: 741.83 KB
# JPEG_20250917_112201_4499249432429427684.jpg -> 4623.58 KB
#    → Comprimida: 1660.00 KB
# JPEG_20250917_112219_7702319617341359160.jpg -> 2414.49 KB
#    → Comprimida: 613.04 KB
# JPEG_20250917_112237_7726603334934486243.jpg -> 3304.66 KB
#    → Comprimida: 1039.41 KB
# JPEG_20250917_112246_2237475291239287107.jpg -> 4315.15 KB
#    → Comprimida: 1586.50 KB
# JPEG_20250917_112256_6104532961766872711.jpg -> 2448.15 KB
#    → Comprimida: 646.43 KB
# JPEG_20250917_112309_8250938238651080873.jpg -> 4735.03 KB
#    → Comprimida: 1868.26 KB
# JPEG_20250917_112321_4849447244685410553.jpg -> 7151.44 KB
#    → Comprimida: 3042.87 KB
# JPEG_20250917_112336_2602729676449665305.jpg -> 4948.19 KB
#    → Comprimida: 1802.44 KB
# JPEG_20250917_113743_8330343408503388266.jpg -> 3732.03 KB
#    → Comprimida: 1377.05 KB
# JPEG_20250917_113952_3229496401555080600.jpg -> 3782.83 KB
#    → Comprimida: 1239.04 KB
# JPEG_20250917_114006_6613209352689604512.jpg -> 2322.10 KB
#    → Comprimida: 449.16 KB
# JPEG_20250917_114107_3376509494478052525.jpg -> 3226.40 KB
#    → Comprimida: 719.04 KB
# JPEG_20250917_114553_8371374826162410775.jpg -> 4730.21 KB
#    → Comprimida: 1769.99 KB
# JPEG_20250917_115005_2389588481352946809.jpg -> 3535.73 KB
#    → Comprimida: 898.34 KB
# JPEG_20250917_115052_3445381153858753763.jpg -> 4528.64 KB
#    → Comprimida: 1669.52 KB
# JPEG_20250917_115105_1684020774525615529.jpg -> 4228.65 KB
#    → Comprimida: 1394.61 KB
# JPEG_20250917_115116_3430903843324838407.jpg -> 2254.57 KB
#    → Comprimida: 655.49 KB
# JPEG_20250917_115347_527085849220001786.jpg -> 3341.59 KB
#    → Comprimida: 1325.26 KB
# JPEG_20250917_115651_2920419563309733432.jpg -> 4126.78 KB
#    → Comprimida: 1502.86 KB
# JPEG_20250917_115704_7027715950508440833.jpg -> 2534.11 KB
#    → Comprimida: 631.14 KB
# JPEG_20250917_115743_6617919614339493352.jpg -> 3497.46 KB
#    → Comprimida: 928.43 KB
# JPEG_20250917_115841_3887824417225158842.jpg -> 3957.40 KB
#    → Comprimida: 1488.44 KB
# JPEG_20250917_120331_2420594018426239719.jpg -> 1986.24 KB
#    → Comprimida: 314.26 KB
# JPEG_20250917_120348_2274991856959695465.jpg -> 4335.27 KB
#    → Comprimida: 1530.88 KB
# JPEG_20250917_120401_8573908679958550648.jpg -> 5179.97 KB
#    → Comprimida: 2047.56 KB
# JPEG_20250917_120454_2017388544268333593.jpg -> 2247.44 KB
#    → Comprimida: 441.26 KB
# JPEG_20250917_120530_6262186013552257187.jpg -> 3553.15 KB
#    → Comprimida: 993.78 KB
# JPEG_20250917_152631_1744619501207176905.jpg -> 5429.17 KB
#    → Comprimida: 2094.01 KB
# JPEG_20250917_152801_5066268056351895926.jpg -> 3282.84 KB
#    → Comprimida: 754.54 KB
# JPEG_20250917_152830_4649248919748345057.jpg -> 4225.07 KB
#    → Comprimida: 1522.01 KB
# JPEG_20250917_152851_7919412219570511202.jpg -> 4584.79 KB
#    → Comprimida: 1580.16 KB
# JPEG_20250917_152921_2443029173621887444.jpg -> 3793.33 KB
#    → Comprimida: 1385.07 KB
# JPEG_20250917_152933_163249808052302743.jpg -> 2301.32 KB
#    → Comprimida: 610.33 KB
# IMG_20250916_151632_2.jpg -> 5742.48 KB
#    → Comprimida: 2418.37 KB
# JPEG_20250916_074709_4036776448313514940.jpg -> 3353.48 KB
#    → Comprimida: 824.13 KB
# JPEG_20250916_074757_2613648838991333237.jpg -> 5996.48 KB
#    → Comprimida: 2601.94 KB
# JPEG_20250916_074846_418292395577327452.jpg -> 4714.61 KB
#    → Comprimida: 1796.46 KB
# JPEG_20250916_074907_7877672103184857666.jpg -> 4773.72 KB
#    → Comprimida: 1833.50 KB
# JPEG_20250916_074917_2104663315484267941.jpg -> 3149.86 KB
#    → Comprimida: 1144.43 KB
# JPEG_20250916_075814_8490289706253845608.jpg -> 5803.38 KB
#    → Comprimida: 2304.41 KB
# JPEG_20250916_075831_3923749857506144911.jpg -> 3803.92 KB
#    → Comprimida: 1510.69 KB
# JPEG_20250916_075844_5997287956778995933.jpg -> 2166.15 KB
#    → Comprimida: 583.00 KB
# JPEG_20250916_080015_5380423369741470893.jpg -> 4252.73 KB
#    → Comprimida: 1428.17 KB
# JPEG_20250916_080043_1699885863228998072.jpg -> 3695.86 KB
#    → Comprimida: 874.79 KB
# JPEG_20250916_080055_744053797043079881.jpg -> 2362.88 KB
#    → Comprimida: 518.26 KB
# JPEG_20250916_080514_6793444667725414958.jpg -> 4030.80 KB
#    → Comprimida: 1367.49 KB
# JPEG_20250916_080532_3415639250681826888.jpg -> 3385.24 KB
#    → Comprimida: 1227.90 KB
# JPEG_20250916_080546_4419086800646686157.jpg -> 3895.87 KB
#    → Comprimida: 1422.48 KB
# JPEG_20250916_080625_6052087859732159573.jpg -> 3732.56 KB
#    → Comprimida: 1249.84 KB
# JPEG_20250916_080746_7346521026071399768.jpg -> 3189.73 KB
#    → Comprimida: 728.82 KB
# JPEG_20250916_081522_9066828122559309148.jpg -> 2790.14 KB
#    → Comprimida: 673.52 KB
# JPEG_20250916_081530_4047126021184645385.jpg -> 3284.80 KB
#    → Comprimida: 1133.02 KB
# JPEG_20250916_081551_9198593203957375132.jpg -> 5095.89 KB
#    → Comprimida: 1921.38 KB
# JPEG_20250916_081656_4571628793849700272.jpg -> 3438.67 KB
#    → Comprimida: 854.93 KB
# JPEG_20250916_081736_7073638925627861555.jpg -> 3886.43 KB
#    → Comprimida: 1309.64 KB
# JPEG_20250916_081802_280999619430668620.jpg -> 3379.85 KB
#    → Comprimida: 843.30 KB
# JPEG_20250916_081832_4171464931224066336.jpg -> 2285.35 KB
#    → Comprimida: 464.60 KB
# JPEG_20250916_082606_7528917243626341371.jpg -> 4677.06 KB
#    → Comprimida: 1770.83 KB
# JPEG_20250916_082734_4785442792742551222.jpg -> 3212.68 KB
#    → Comprimida: 774.88 KB
# JPEG_20250916_082748_1320369447760261777.jpg -> 2523.86 KB
#    → Comprimida: 640.06 KB
# JPEG_20250916_082759_4401268740398705139.jpg -> 4481.07 KB
#    → Comprimida: 1735.96 KB
# JPEG_20250916_083800_394971501137189400.jpg -> 3901.74 KB
#    → Comprimida: 1618.17 KB
# JPEG_20250916_083855_4302535827706947787.jpg -> 2888.45 KB
#    → Comprimida: 748.19 KB
# JPEG_20250916_083910_9220493641255143025.jpg -> 4156.65 KB
#    → Comprimida: 1369.72 KB
# JPEG_20250916_083920_7220939460727964540.jpg -> 2464.67 KB
#    → Comprimida: 475.89 KB
# JPEG_20250916_084332_802631651976541333.jpg -> 5113.71 KB
#    → Comprimida: 2039.93 KB
# JPEG_20250916_084347_3715613020054810958.jpg -> 3171.18 KB
#    → Comprimida: 905.29 KB
# JPEG_20250916_084409_5907256247027891555.jpg -> 4721.06 KB
#    → Comprimida: 1928.92 KB
# JPEG_20250916_084430_6736033551362682669.jpg -> 4531.85 KB
#    → Comprimida: 1712.13 KB
# JPEG_20250916_084437_5919871070983076600.jpg -> 2878.66 KB
#    → Comprimida: 1028.46 KB
# JPEG_20250916_084539_3873705312052615694.jpg -> 3748.76 KB
#    → Comprimida: 897.54 KB
# JPEG_20250916_085140_3405039999665463586.jpg -> 3441.18 KB
#    → Comprimida: 1126.47 KB
# JPEG_20250916_085157_9043362731158596631.jpg -> 2332.49 KB
#    → Comprimida: 463.62 KB
# JPEG_20250916_085213_4958868505087199209 (1).jpg -> 3311.86 KB
#    → Comprimida: 1016.39 KB
# JPEG_20250916_085227_3481875251731035048.jpg -> 2438.75 KB
#    → Comprimida: 405.31 KB
# JPEG_20250916_085317_6123077698088121916.jpg -> 3998.70 KB
#    → Comprimida: 995.81 KB
# JPEG_20250916_090115_7472350043369769313.jpg -> 5538.09 KB
#    → Comprimida: 2332.21 KB
# JPEG_20250916_090134_899272839135339698.jpg -> 4393.19 KB
#    → Comprimida: 1522.37 KB
# JPEG_20250916_090147_3372494979883465256.jpg -> 2730.57 KB
#    → Comprimida: 922.45 KB
# JPEG_20250916_090227_3115831209829880089.jpg -> 4055.91 KB
#    → Comprimida: 1618.76 KB
# JPEG_20250916_090318_3448307538366743794.jpg -> 3386.61 KB
#    → Comprimida: 904.83 KB
# JPEG_20250916_090948_6983097293296670111.jpg -> 4065.13 KB
#    → Comprimida: 1458.12 KB
# JPEG_20250916_091359_9009623443114530216.jpg -> 3023.51 KB
#    → Comprimida: 762.24 KB
# JPEG_20250916_091419_8999838772711589199.jpg -> 2687.44 KB
#    → Comprimida: 536.20 KB
# JPEG_20250916_091431_340828449349551233.jpg -> 2418.30 KB
#    → Comprimida: 552.96 KB
# JPEG_20250916_091443_421487835375570979.jpg -> 3388.69 KB
#    → Comprimida: 1170.42 KB
# JPEG_20250916_092219_843120071577040532.jpg -> 3504.35 KB
#    → Comprimida: 1253.26 KB
# JPEG_20250916_092246_4179661401321805937.jpg -> 4026.13 KB
#    → Comprimida: 1541.78 KB
# JPEG_20250916_092305_7001987421043061113.jpg -> 2461.61 KB
#    → Comprimida: 498.57 KB
# JPEG_20250916_092314_4257404466205912384.jpg -> 2317.56 KB
#    → Comprimida: 501.60 KB
# JPEG_20250916_092413_7771251383994279511.jpg -> 3043.20 KB
#    → Comprimida: 778.61 KB
# IMG_20250908_213231_2.jpg -> 156.11 KB
#    → Copiada sin cambios (156.11 KB)
# IMG_20250917_105745_0.jpg -> 5525.59 KB
#    → Comprimida: 1979.40 KB
# IMG_20250917_105546_0.jpg -> 6759.64 KB
#    → Comprimida: 2670.95 KB
# IMG_20250917_094529_3.jpg -> 5822.99 KB
#    → Comprimida: 2264.56 KB
# IMG_20250917_094529_2.jpg -> 5727.68 KB
#    → Comprimida: 2103.90 KB
# IMG_20250917_094529_1.jpg -> 5685.25 KB
#    → Comprimida: 2091.78 KB
# IMG_20250917_094529_0.jpg -> 6514.12 KB
#    → Comprimida: 2541.27 KB
# IMG_20250917_092541_6.jpg -> 5650.22 KB
#    → Comprimida: 2122.57 KB
# IMG_20250917_092541_5.jpg -> 5184.70 KB
#    → Comprimida: 1766.39 KB
# IMG_20250917_092541_4.jpg -> 4130.68 KB
#    → Comprimida: 1140.44 KB
# IMG_20250917_092541_3.jpg -> 4016.98 KB
#    → Comprimida: 1073.92 KB
# IMG_20250917_092541_2.jpg -> 5595.33 KB
#    → Comprimida: 2016.18 KB
# IMG_20250917_092541_1.jpg -> 4016.27 KB
#    → Comprimida: 1088.13 KB
# IMG_20250917_092541_0.jpg -> 4115.79 KB
#    → Comprimida: 1158.07 KB
# IMG_20250917_084839_1.jpg -> 8735.91 KB
#    → Comprimida: 1251.30 KB
# IMG_20250917_084839_0.jpg -> 9401.20 KB
#    → Comprimida: 1492.88 KB
# JPEG_20250917_082820_1911484470502720080.jpg -> 4149.02 KB
#    → Comprimida: 1470.30 KB
# JPEG_20250917_082736_5199952920247290689.jpg -> 7880.97 KB
#    → Comprimida: 3327.49 KB
# JPEG_20250917_082724_164056103689872441.jpg -> 6013.62 KB
#    → Comprimida: 2419.14 KB
# IMG_20250917_114958_0.jpg -> 4998.53 KB
#    → Comprimida: 1663.80 KB
# IMG_20250917_114707_3.jpg -> 5931.61 KB
#    → Comprimida: 2264.89 KB
# IMG_20250917_114707_2.jpg -> 4818.54 KB
#    → Comprimida: 1712.23 KB
# IMG_20250917_114707_1.jpg -> 5024.49 KB
#    → Comprimida: 1796.34 KB
# IMG_20250917_114707_0.jpg -> 4744.98 KB
#    → Comprimida: 1687.73 KB
# IMG_20250917_113610_0.jpg -> 5437.75 KB
#    → Comprimida: 2076.59 KB
# IMG_20250917_113524_2.jpg -> 5508.58 KB
#    → Comprimida: 2042.26 KB
# IMG_20250917_113524_1.jpg -> 4172.17 KB
#    → Comprimida: 1301.37 KB
# IMG_20250917_113524_0.jpg -> 3876.27 KB
#    → Comprimida: 981.07 KB
# IMG_20250917_105547_3.jpg -> 6050.06 KB
#    → Comprimida: 2277.28 KB
# IMG_20250917_105547_2.jpg -> 3703.11 KB
#    → Comprimida: 908.12 KB
# IMG_20250917_105547_1.jpg -> 5638.08 KB
#    → Comprimida: 2034.71 KB
# JPEG_20250917_115156_1337351064045899074.jpg -> 1499.98 KB
#    → Comprimida: 363.38 KB
# JPEG_20250917_115144_6854224413466410914.jpg -> 5923.52 KB
#    → Comprimida: 2252.97 KB
# JPEG_20250917_115032_8664507144120488475.jpg -> 4103.83 KB
#    → Comprimida: 1506.11 KB
# JPEG_20250917_112537_3359105391413848413.jpg -> 6544.73 KB
#    → Comprimida: 2794.57 KB
# JPEG_20250917_112528_8514050483002133982.jpg -> 7886.67 KB
# Error con JPEG_20250917_112528_8514050483002133982.jpg: [WinError 53] The network path was not found: '\\\\192.168.1.2\\cenyt-proyectos\\CEN-221_ANDA\\2.INFOENTRADA\\5. Inspeccion Redes\\2025-09-15\\ANDA-REDES\\Comprimidas\\JPEG_20250917_112528_8514050483002133982.jpg'

# %%
import os
import shutil
from PIL import Image

# Carpetas
carpeta = r"C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas"
carpeta_salida = r"C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_2"
os.makedirs(carpeta_salida, exist_ok=True)

# Límite en KB
limite_kb = 49

# Listado de archivos originales y ya procesados
archivos_entrada = {f for f in os.listdir(carpeta) if f.lower().endswith(('.jpg', '.jpeg', '.png'))}
archivos_salida = {f for f in os.listdir(carpeta_salida) if f.lower().endswith(('.jpg', '.jpeg', '.png'))}

# Calcular los pendientes
pendientes = archivos_entrada - archivos_salida

print(f"Total imágenes en carpeta: {len(archivos_entrada)}")
print(f"Ya procesadas: {len(archivos_salida)}")
print(f"Pendientes: {len(pendientes)}")

for archivo in pendientes:
    ruta = os.path.join(carpeta, archivo)
    destino = os.path.join(carpeta_salida, archivo)

    if os.path.isfile(ruta):
        tamano_kb = os.path.getsize(ruta) / 1024
        print(f"{archivo} -> {tamano_kb:.2f} KB")

        if tamano_kb <= limite_kb:
            # Copiar directamente
            shutil.copy2(ruta, destino)
            print(f"   → Copiada sin cambios ({tamano_kb:.2f} KB)")
        else:
            # Comprimir
            try:
                img = Image.open(ruta)
                if archivo.lower().endswith(('.jpg', '.jpeg')):
                    img.save(destino, optimize=True, quality=70)
                else:
                    img.save(destino, optimize=True)

                nuevo_tamano = os.path.getsize(destino) / 1024
                print(f"   → Comprimida: {nuevo_tamano:.2f} KB")

            except Exception as e:
                print(f"Error con {archivo}: {e}")
# Out:
# Total imágenes en carpeta: 523
# Ya procesadas: 0
# Pendientes: 523
# JPEG_20250916_100034_4279327063874974096.jpg -> 1364.22 KB
#    → Comprimida: 1364.22 KB
# IMG_20250917_092541_6.jpg -> 2122.57 KB
#    → Comprimida: 2121.91 KB
# IMG_20250917_114707_0.jpg -> 1687.73 KB
#    → Comprimida: 1686.37 KB
# JPEG_20250916_152333_8056945582870247404.jpg -> 1579.24 KB
#    → Comprimida: 1579.25 KB
# JPEG_20250916_090227_3115831209829880089.jpg -> 1618.76 KB
#    → Comprimida: 1618.39 KB
# IMG_20250916_112256_11.jpg -> 214.56 KB
#    → Comprimida: 214.44 KB
# IMG_20250915_181638_1.jpg -> 459.23 KB
#    → Comprimida: 178.97 KB
# IMG_20250913_155434_2.jpg -> 793.11 KB
#    → Comprimida: 792.99 KB
# JPEG_20250916_112005_7434297881446057555.jpg -> 947.35 KB
#    → Comprimida: 947.31 KB
# JPEG_20250917_080303_116016971314641476.jpg -> 2316.74 KB
#    → Comprimida: 2316.08 KB
# JPEG_20250904_104626_5068251037143720812.jpg -> 1685.93 KB
#    → Comprimida: 1685.78 KB
# JPEG_20250917_102827_299399395532826017.jpg -> 456.71 KB
#    → Comprimida: 456.65 KB
# JPEG_20250917_112246_2237475291239287107.jpg -> 1586.50 KB
#    → Comprimida: 1586.54 KB
# JPEG_20250916_083800_394971501137189400.jpg -> 1618.17 KB
#    → Comprimida: 1618.16 KB
# JPEG_20250917_115743_6617919614339493352.jpg -> 928.43 KB
#    → Comprimida: 928.29 KB
# IMG_20250913_150726_0 1.jpg -> 560.35 KB
#    → Comprimida: 560.31 KB
# IMG_20250915_172839_1.jpg -> 242.87 KB
#    → Comprimida: 242.81 KB
# JPEG_20250916_100927_8430370198578132454.jpg -> 1687.80 KB
#    → Comprimida: 1687.44 KB
# IMG_20250916_150739_10.jpg -> 164.62 KB
#    → Comprimida: 164.59 KB
# JPEG_20250916_082606_7528917243626341371.jpg -> 1770.83 KB
#    → Comprimida: 1770.03 KB
# JPEG_20250916_085157_9043362731158596631.jpg -> 463.62 KB
#    → Comprimida: 463.61 KB
# JPEG_20250917_115156_1337351064045899074.jpg -> 363.38 KB
#    → Comprimida: 363.37 KB
# IMG_20250916_114309_5.jpg -> 47.09 KB
#    → Copiada sin cambios (47.09 KB)
# IMG_20250916_114309_2.jpg -> 67.41 KB
#    → Comprimida: 67.42 KB
# JPEG_20250913_104632_6748894105590554641.jpg -> 2457.13 KB
#    → Comprimida: 2456.20 KB
# JPEG_20250917_114553_8371374826162410775.jpg -> 1769.99 KB
#    → Comprimida: 1769.56 KB
# IMG_20250915_165215_3.jpg -> 212.07 KB
#    → Comprimida: 212.06 KB
# IMG_20250908_133053_2.jpg -> 497.64 KB
#    → Comprimida: 497.59 KB
# IMG_20250913_150726_1.jpg -> 1210.50 KB
#    → Comprimida: 1210.40 KB
# JPEG_20250916_100733_6575384977338099202.jpg -> 459.48 KB
#    → Comprimida: 459.46 KB
# JPEG_20250917_152933_163249808052302743.jpg -> 610.33 KB
#    → Comprimida: 610.21 KB
# JPEG_20250916_110031_573387656141485015.jpg -> 895.35 KB
#    → Comprimida: 895.13 KB
# IMG_20250913_151349_1.jpg -> 894.22 KB
#    → Comprimida: 894.19 KB
# JPEG_20250917_103402_4457903689002376995.jpg -> 1731.08 KB
#    → Comprimida: 1730.60 KB
# JPEG_20250913_112822_3370316098664628644 1.jpg -> 283.64 KB
#    → Comprimida: 283.61 KB
# JPEG_20250917_105813_7140297239385125550.jpg -> 1193.36 KB
#    → Comprimida: 1193.28 KB
# JPEG_20250917_112528_8514050483002133982.jpg -> 2048.00 KB
# Error con JPEG_20250917_112528_8514050483002133982.jpg: image file is truncated (73 bytes not processed)
# JPEG_20250913_103606_2971287701104281848.jpg -> 622.79 KB
#    → Comprimida: 622.70 KB
# JPEG_20250916_082734_4785442792742551222.jpg -> 774.88 KB
#    → Comprimida: 774.76 KB
# JPEG_20250917_101558_3129433922930626672.jpg -> 1662.48 KB
#    → Comprimida: 1662.35 KB
# JPEG_20250913_112808_3363529334726761411.jpg -> 568.86 KB
#    → Comprimida: 568.90 KB
# IMG_20250916_112255_4.jpg -> 184.24 KB
#    → Comprimida: 184.17 KB
# JPEG_20250916_093804_1476026317747796236.jpg -> 766.33 KB
#    → Comprimida: 766.22 KB
# JPEG_20250917_104758_4483151122974804118.jpg -> 785.76 KB
#    → Comprimida: 785.65 KB
# IMG_20250908_133053_1.jpg -> 1274.76 KB
#    → Comprimida: 1274.67 KB
# JPEG_20250917_111050_3238503415271855838.jpg -> 589.61 KB
#    → Comprimida: 589.59 KB
# JPEG_20250917_120331_2420594018426239719.jpg -> 314.26 KB
#    → Comprimida: 314.20 KB
# JPEG_20250916_081530_4047126021184645385.jpg -> 1133.02 KB
#    → Comprimida: 1133.04 KB
# IMG_20250915_182651_2.jpg -> 494.36 KB
#    → Comprimida: 193.79 KB
# JPEG_20250916_083920_7220939460727964540.jpg -> 475.89 KB
#    → Comprimida: 475.91 KB
# JPEG_20250917_114006_6613209352689604512.jpg -> 449.16 KB
#    → Comprimida: 449.08 KB
# IMG_20250915_165215_2.jpg -> 255.22 KB
#    → Comprimida: 255.21 KB
# JPEG_20250916_085140_3405039999665463586.jpg -> 1126.47 KB
#    → Comprimida: 1126.39 KB
# JPEG_20250916_094007_6368269594654488186.jpg -> 914.47 KB
#    → Comprimida: 914.50 KB
# IMG_20250913_152712_3.jpg -> 1367.48 KB
#    → Comprimida: 1367.40 KB
# JPEG_20250916_110618_203552646599540277.jpg -> 1949.80 KB
#    → Comprimida: 1949.53 KB
# IMG_20250915_184854_8.jpg -> 1458.41 KB
#    → Comprimida: 1458.50 KB
# JPEG_20250916_081802_280999619430668620.jpg -> 843.30 KB
#    → Comprimida: 843.27 KB
# JPEG_20250917_115651_2920419563309733432.jpg -> 1502.86 KB
#    → Comprimida: 1502.69 KB
# IMG_20250916_112255_2.jpg -> 65.49 KB
#    → Comprimida: 65.47 KB
# JPEG_20250916_102906_5687610359794887634.jpg -> 1145.82 KB
#    → Comprimida: 1145.77 KB
# JPEG_20250916_095232_4109838746184893074.jpg -> 730.16 KB
#    → Comprimida: 729.97 KB
# JPEG_20250916_105900_3749144735506074880.jpg -> 1602.65 KB
#    → Comprimida: 1602.60 KB
# JPEG_20250916_094644_3383976405256983050.jpg -> 1194.80 KB
#    → Comprimida: 1194.97 KB
# JPEG_20250916_144704_6638611620408645975.jpg -> 1596.98 KB
#    → Comprimida: 1596.88 KB
# JPEG_20250916_102917_6696304646052440864.jpg -> 1797.54 KB
#    → Comprimida: 1796.99 KB
# JPEG_20250913_112822_3370316098664628644.jpg -> 283.64 KB
#    → Comprimida: 283.61 KB
# JPEG_20250916_081656_4571628793849700272.jpg -> 854.93 KB
#    → Comprimida: 854.95 KB
# JPEG_20250916_074757_2613648838991333237.jpg -> 2601.94 KB
#    → Comprimida: 2601.06 KB
# IMG_20250915_180030_0.jpg -> 328.33 KB
#    → Comprimida: 328.27 KB
# IMG_20250913_150033_2.jpg -> 63.51 KB
#    → Comprimida: 63.52 KB
# IMG_20250913_155434_1.jpg -> 826.17 KB
#    → Comprimida: 826.11 KB
# JPEG_20250916_104401_7252379617681325003.jpg -> 409.20 KB
#    → Comprimida: 409.20 KB
# JPEG_20250916_095922_8393590414058177649.jpg -> 1163.30 KB
#    → Comprimida: 1163.09 KB
# JPEG_20250916_102825_3487687522954874181.jpg -> 1272.52 KB
#    → Comprimida: 1272.46 KB
# JPEG_20250917_095953_6924516208807664186.jpg -> 591.78 KB
#    → Comprimida: 591.79 KB
# IMG_20250913_155434_0.jpg -> 1228.96 KB
#    → Comprimida: 1228.80 KB
# JPEG_20250916_080746_7346521026071399768.jpg -> 728.82 KB
#    → Comprimida: 728.59 KB
# IMG_20250916_145302_12.jpg -> 210.85 KB
#    → Comprimida: 210.77 KB
# IMG_20250913_145105_0.jpg -> 985.70 KB
#    → Comprimida: 985.77 KB
# IMG_20250913_145848_0 1.jpg -> 942.83 KB
#    → Comprimida: 942.58 KB
# IMG_20250917_084839_0.jpg -> 1492.88 KB
#    → Comprimida: 1492.29 KB
# IMG_20250913_150726_2 1.jpg -> 1716.54 KB
#    → Comprimida: 1716.33 KB
# JPEG_20250904_102212_6787764060378165695.jpg -> 781.49 KB
#    → Comprimida: 781.55 KB
# JPEG_20250916_093746_421050134540274992.jpg -> 1864.25 KB
#    → Comprimida: 1862.83 KB
# JPEG_20250916_152438_8460943030392295835.jpg -> 1072.25 KB
#    → Comprimida: 1072.17 KB
# JPEG_20250916_111049_8278072253293669347.jpg -> 408.01 KB
#    → Comprimida: 408.00 KB
# JPEG_20250917_113743_8330343408503388266.jpg -> 1377.05 KB
#    → Comprimida: 1376.86 KB
# IMG_20250915_184854_2.jpg -> 237.72 KB
#    → Comprimida: 237.74 KB
# IMG_20250917_113524_2.jpg -> 2042.26 KB
#    → Comprimida: 2038.92 KB
# JPEG_20250917_102852_7630995914794708945.jpg -> 1213.90 KB
#    → Comprimida: 1213.90 KB
# IMG_20250909_183855_1.jpg -> 84.77 KB
#    → Comprimida: 40.62 KB
# JPEG_20250913_105537_2639509893398097532 1.jpg -> 1504.62 KB
#    → Comprimida: 1504.48 KB
# IMG_20250915_171046_0.jpg -> 327.63 KB
#    → Comprimida: 99.01 KB
# IMG_20250913_150726_2.jpg -> 1716.54 KB
#    → Comprimida: 1716.33 KB
# IMG_20250913_155847_0.jpg -> 1203.16 KB
#    → Comprimida: 1203.05 KB
# JPEG_20250917_080332_121774368355761287.jpg -> 1219.93 KB
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 41
#      39 img = Image.open(ruta)
#      40 if archivo.lower().endswith(('.jpg', '.jpeg')):
# ---> 41     img.save(destino, optimize=True, quality=70)
#      42 else:
#      43     img.save(destino, optimize=True)
#
# File c:\Users\ingju\AppData\Local\Programs\Python\Python313\Lib\site-packages\PIL\Image.py:2551, in Image.save(self, fp, format, **params)
#    2549     self._ensure_mutable()
#    2550 else:
# -> 2551     self.load()
#    2553 save_all = params.pop("save_all", None)
#    2554 self.encoderinfo = {**getattr(self, "encoderinfo", {}), **params}
#
# File c:\Users\ingju\AppData\Local\Programs\Python\Python313\Lib\site-packages\PIL\ImageFile.py:389, in ImageFile.load(self)
#     386         raise OSError(msg)
#     388 b = b + s
# --> 389 n, err_code = decoder.decode(b)
#     390 if n < 0:
#     391     break
#
# KeyboardInterrupt:

# %%
import os
import shutil
from PIL import Image


# Carpetas
carpeta = r"C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas"
carpeta_salida = r"C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas_2"
os.makedirs(carpeta_salida, exist_ok=True)
# Límite en KB
limite_kb = 49

# Archivos pendientes
archivos_entrada = {f for f in os.listdir(carpeta) if f.lower().endswith(('.jpg', '.jpeg', '.png'))}
archivos_salida = {f for f in os.listdir(carpeta_salida) if f.lower().endswith(('.jpg', '.jpeg', '.png'))}
pendientes = archivos_entrada - archivos_salida

print(f"Total imágenes en carpeta: {len(archivos_entrada)}")
print(f"Ya procesadas: {len(archivos_salida)}")
print(f"Pendientes: {len(pendientes)}")

def comprimir_imagen(ruta, destino, limite_kb, calidad_inicial=85, paso=5, factor_resize=0.9):
    """
    Comprime una imagen reduciendo calidad y dimensiones hasta que
    esté por debajo del límite en KB.
    """
    try:
        img = Image.open(ruta)

        # Si es PNG → convertir a JPG (mejor compresión)
        if ruta.lower().endswith(".png"):
            img = img.convert("RGB")
            destino = os.path.splitext(destino)[0] + ".jpg"

        calidad = calidad_inicial
        ancho, alto = img.size

        while True:
            # Guardar temporalmente
            img.save(destino, optimize=True, quality=calidad)
            tamano_kb = os.path.getsize(destino) / 1024

            if tamano_kb <= limite_kb:
                return tamano_kb

            # Bajar calidad primero
            if calidad > 20:
                calidad -= paso
            else:
                # Si la calidad ya está muy baja, reducimos dimensiones
                ancho = int(ancho * factor_resize)
                alto = int(alto * factor_resize)
                img = img.resize((ancho, alto), Image.LANCZOS)

            # Si llega a ser muy pequeña y no logra el peso, salimos
            if ancho < 200 or alto < 200:
                return tamano_kb

    except Exception as e:
        print(f"   Error al comprimir {ruta}: {e}")
        return None

# Procesar archivos pendientes
for archivo in pendientes:
    ruta = os.path.join(carpeta, archivo)
    destino = os.path.join(carpeta_salida, archivo)

    if os.path.isfile(ruta):
        tamano_kb = os.path.getsize(ruta) / 1024
        print(f"{archivo} -> {tamano_kb:.2f} KB")

        if tamano_kb <= limite_kb:
            shutil.copy2(ruta, destino)
            print(f"   → Copiada sin cambios ({tamano_kb:.2f} KB)")
        else:
            nuevo_tamano = comprimir_imagen(ruta, destino, limite_kb)
            if nuevo_tamano:
                print(f"   → Comprimida: {nuevo_tamano:.2f} KB")
# Out:
# Total imágenes en carpeta: 523
# Ya procesadas: 95
# Pendientes: 428
# JPEG_20250917_112528_8514050483002133982.jpg -> 2048.00 KB
#    Error al comprimir C:\Users\ingju\OneDrive - Cenyt ingenieros\Desktop\Anda\Comprimidas\JPEG_20250917_112528_8514050483002133982.jpg: image file is truncated (73 bytes not processed)
# JPEG_20250917_080332_121774368355761287.jpg -> 1219.93 KB
#    → Comprimida: 42.01 KB
# IMG_20250916_145302_9.jpg -> 165.77 KB
#    → Comprimida: 41.65 KB
# IMG_20250915_171046_2.jpg -> 242.87 KB
#    → Comprimida: 47.96 KB
# JPEG_20250904_104701_6614820806790020965.jpg -> 999.90 KB
#    → Comprimida: 44.96 KB
# IMG_20250916_110018_3.jpg -> 88.27 KB
#    → Comprimida: 47.03 KB
# IMG_20250917_105546_0.jpg -> 2670.95 KB
#    → Comprimida: 46.91 KB
# JPEG_20250917_082724_164056103689872441.jpg -> 2419.14 KB
#    → Comprimida: 48.89 KB
# IMG_20250915_154833_1.jpg -> 419.37 KB
#    → Comprimida: 46.90 KB
# JPEG_20250916_152359_1150534399233289806.jpg -> 485.85 KB
#    → Comprimida: 42.27 KB
# JPEG_20250916_094708_7232212427773938900.jpg -> 1532.49 KB
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 76
#      74     print(f"   → Copiada sin cambios ({tamano_kb:.2f} KB)")
#      75 else:
# ---> 76     nuevo_tamano = comprimir_imagen(ruta, destino, limite_kb)
#      77     if nuevo_tamano:
#      78         print(f"   → Comprimida: {nuevo_tamano:.2f} KB")
#
# Cell In[4], line 40, in comprimir_imagen(ruta, destino, limite_kb, calidad_inicial, paso, factor_resize)
#      36 ancho, alto = img.size
#      38 while True:
#      39     # Guardar temporalmente
# ---> 40     img.save(destino, optimize=True, quality=calidad)
#      41     tamano_kb = os.path.getsize(destino) / 1024
#      43     if tamano_kb <= limite_kb:
#
# File c:\Users\ingju\AppData\Local\Programs\Python\Python313\Lib\site-packages\PIL\Image.py:2581, in Image.save(self, fp, format, **params)
#    2578     fp = cast(IO[bytes], fp)
#    2580 try:
# -> 2581     save_handler(self, fp, filename)
#    2582 except Exception:
#    2583     if open_fp:
#
# File c:\Users\ingju\AppData\Local\Programs\Python\Python313\Lib\site-packages\PIL\JpegImagePlugin.py:853, in _save(im, fp, filename)
#     848 else:
#     849     # The EXIF info needs to be written as one block, + APP1, + one spare byte.
#     850     # Ensure that our buffer is big enough. Same with the icc_profile block.
#     851     bufsize = max(bufsize, len(exif) + 5, len(extra) + 1)
# --> 853 ImageFile._save(
#     854     im, fp, [ImageFile._Tile("jpeg", (0, 0) + im.size, 0, rawmode)], bufsize
#     855 )
#
# File c:\Users\ingju\AppData\Local\Programs\Python\Python313\Lib\site-packages\PIL\ImageFile.py:645, in _save(im, fp, tile, bufsize)
#     643     fh = fp.fileno()
#     644     fp.flush()
# --> 645     _encode_tile(im, fp, tile, bufsize, fh)
#     646 except (AttributeError, io.UnsupportedOperation) as exc:
#     647     _encode_tile(im, fp, tile, bufsize, None, exc)
#
# File c:\Users\ingju\AppData\Local\Programs\Python\Python313\Lib\site-packages\PIL\ImageFile.py:680, in _encode_tile(im, fp, tile, bufsize, fh, exc)
#     677     else:
#     678         # slight speedup: compress to real file object
#     679         assert fh is not None
# --> 680         errcode = encoder.encode_to_file(fh, bufsize)
#     681 if errcode < 0:
#     682     raise _get_oserror(errcode, encoder=True) from exc
#
# KeyboardInterrupt:
